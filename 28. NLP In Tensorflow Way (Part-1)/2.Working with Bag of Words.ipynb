# %% [markdown]
# # Working with Bag of Words

# %% [markdown]
# In this example, we will download and preprocess the ham/spam text data. We will then use a one-hot-encoding to make a bag of words set of features to use in logistic regression.
#
# We will use these one-hot-vectors for logistic regression to predict if a text is spam or ham.
#
# We start by loading the necessary libraries.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import numpy as np
import csv
import string
import requests
import io
from zipfile import ZipFile
from tensorflow.contrib import learn
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Start a graph session
sess = tf.Session()

# %%
save_file_name = os.path.join('temp','temp_spam_data.csv')

# Create directory if it doesn't exist
if not os.path.exists('temp'):
    os.makedirs('temp')

if os.path.isfile(save_file_name):
    text_data = []
    with open(save_file_name, 'r') as temp_output_file:
        reader = csv.reader(temp_output_file)
        for row in reader:
            text_data.append(row)
else:
    zip_url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip'
    r = requests.get(zip_url)
    z = ZipFile(io.BytesIO(r.content))
    file = z.read('SMSSpamCollection')
    # Format Data
    text_data = file.decode()
    text_data = text_data.encode('ascii',errors='ignore')
    text_data = text_data.decode().split('\n')
    text_data = [x.split('\t') for x in text_data if len(x)>=1]
    
    # And write to csv
    with open(save_file_name, 'w') as temp_output_file:
        writer = csv.writer(temp_output_file)
        writer.writerows(text_data)

texts = [x[1] for x in text_data]
target = [x[0] for x in text_data]

# %% [markdown]
# To reduce the potential vocabulary size, we normalize the text. To do this, we remove the influence of capitalization and numbers in the text.

# %%
# Relabel 'spam' as 1, 'ham' as 0
target = [1 if x=='spam' else 0 for x in target]

# Normalize text
# Lower case
texts = [x.lower() for x in texts]

# Remove punctuation
texts = [''.join(c for c in x if c not in string.punctuation) for x in texts]

# Remove numbers
texts = [''.join(c for c in x if c not in '0123456789') for x in texts]

# Trim extra whitespace
texts = [' '.join(x.split()) for x in texts]

# %% [markdown]
# To determine a good sentence length to pad/crop at, we plot a histogram of text lengths (in words).

# %%
# %matplotlib inline
# Plot histogram of text lengths
text_lengths = [len(x.split()) for x in texts]
text_lengths = [x for x in text_lengths if x < 50]
plt.hist(text_lengths, bins=25)
plt.title('Histogram of # of Words in Texts')
plt.show()

# %% [markdown]
# We crop/pad all texts to be 25 words long. We also will filter out any words that do not appear at least 3 times.

# %%
# Choose max text word length at 25
sentence_size = 25
min_word_freq = 3

# %% [markdown]
# TensorFlow has a built in text processing function called VocabularyProcessor(). We use this function to process the texts.

# %%
# Setup vocabulary processor
vocab_processor = learn.preprocessing.VocabularyProcessor(sentence_size, min_frequency=min_word_freq)

# Have to fit transform to get length of unique words.
vocab_processor.transform(texts)
transformed_texts = np.array([x for x in vocab_processor.transform(texts)])
embedding_size = len(np.unique(transformed_texts))

# %% [markdown]
# To test our logistic model (predicting spam/ham), we split the texts into a train and test set.

# %%
# Split up data set into train/test
train_indices = np.random.choice(len(texts), round(len(texts)*0.8), replace=False)
test_indices = np.array(list(set(range(len(texts))) - set(train_indices)))
texts_train = [x for ix, x in enumerate(texts) if ix in train_indices]
texts_test = [x for ix, x in enumerate(texts) if ix in test_indices]
target_train = [x for ix, x in enumerate(target) if ix in train_indices]
target_test = [x for ix, x in enumerate(target) if ix in test_indices]

# %% [markdown]
# For one-hot-encoding, we setup an identity matrix for the TensorFlow embedding lookup.
#
# We also create the variables and placeholders for the logistic regression we will perform.

# %%
# Setup Index Matrix for one-hot-encoding
identity_mat = tf.diag(tf.ones(shape=[embedding_size]))

# Create variables for logistic regression
A = tf.Variable(tf.random_normal(shape=[embedding_size,1]))
b = tf.Variable(tf.random_normal(shape=[1,1]))

# Initialize placeholders
x_data = tf.placeholder(shape=[sentence_size], dtype=tf.int32)
y_target = tf.placeholder(shape=[1, 1], dtype=tf.float32)

# %% [markdown]
# Next, we create the text-word embedding lookup with the prior identity matrix.
#
# Our logistic regression will use the counts of the words as the input. The counts are created by summing the embedding output across the rows.
#
# Then we declare the logistic regression operations. Note that we do not wrap the logistic operations in the sigmoid function because this will be done in the loss function later on.

# %%
# Text-Vocab Embedding
x_embed = tf.nn.embedding_lookup(identity_mat, x_data)
x_col_sums = tf.reduce_sum(x_embed, 0)

# Declare model operations
x_col_sums_2D = tf.expand_dims(x_col_sums, 0)
model_output = tf.add(tf.matmul(x_col_sums_2D, A), b)

# %% [markdown]
# Now we declare our loss function (which has the sigmoid built in), prediction operations, optimizer, and initialize the variables.

# %%
# Declare loss function (Cross Entropy loss)
loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=model_output, labels=y_target))

# Prediction operation
prediction = tf.sigmoid(model_output)

# Declare optimizer
my_opt = tf.train.GradientDescentOptimizer(0.001)
train_step = my_opt.minimize(loss)

# Intitialize Variables
init = tf.global_variables_initializer()
sess.run(init)

# %% [markdown]
# Now we loop through the iterations and fit the logistic regression on wether or not the text is spam or ham.

# %%
# Start Logistic Regression
print('Starting Training Over {} Sentences.'.format(len(texts_train)))
loss_vec = []
train_acc_all = []
train_acc_avg = []
for ix, t in enumerate(vocab_processor.fit_transform(texts_train)):
    y_data = [[target_train[ix]]]
    
    
    sess.run(train_step, feed_dict={x_data: t, y_target: y_data})
    temp_loss = sess.run(loss, feed_dict={x_data: t, y_target: y_data})
    loss_vec.append(temp_loss)
    
    if (ix+1)%10==0:
        print('Training Observation #' + str(ix+1) + ': Loss = ' + str(temp_loss))
        
    # Keep trailing average of past 50 observations accuracy
    # Get prediction of single observation
    [[temp_pred]] = sess.run(prediction, feed_dict={x_data:t, y_target:y_data})
    # Get True/False if prediction is accurate
    train_acc_temp = target_train[ix]==np.round(temp_pred)
    train_acc_all.append(train_acc_temp)
    if len(train_acc_all) >= 50:
        train_acc_avg.append(np.mean(train_acc_all[-50:]))
# Out:
# Starting Training Over 4459 Sentences.
# Training Observation #10: Loss = 8.575536
# Training Observation #20: Loss = 1.290338
# Training Observation #30: Loss = 5.829224
# Training Observation #40: Loss = 0.000519167
# Training Observation #50: Loss = 1.5485662e-09
# Training Observation #60: Loss = 3.7134804e-08
# Training Observation #70: Loss = 4.3904515e-07
# Training Observation #80: Loss = 2.1267135e-05
# Training Observation #90: Loss = 9.057726e-06
# Training Observation #100: Loss = 1.999514e-06
# Training Observation #110: Loss = 1.18149e-08
# Training Observation #120: Loss = 0.0046767616
# Training Observation #130: Loss = 1.7409553e-07
# Training Observation #140: Loss = 4.3768414e-05
# Training Observation #150: Loss = 0.008443116
# Training Observation #160: Loss = 0.0006958496
# Training Observation #170: Loss = 1.3176272e-05
# Training Observation #180: Loss = 5.5769084e-07
# Training Observation #190: Loss = 1.284072e-06
# Training Observation #200: Loss = 0.5634602
# Training Observation #210: Loss = 3.4330835e-05
# Training Observation #220: Loss = 4.172395e-06
# Training Observation #230: Loss = 2.9495893
# Training Observation #240: Loss = 2.402997e-07
# Training Observation #250: Loss = 1.0824837e-07
# Training Observation #260: Loss = 11.7739315
# Training Observation #270: Loss = 7.944061e-06
# Training Observation #280: Loss = 2.5448483e-06
# Training Observation #290: Loss = 1.7233644e-05
# Training Observation #300: Loss = 0.0001340155
# Training Observation #310: Loss = 3.1201864e-07
# Training Observation #320: Loss = 3.4699788e-05
# Training Observation #330: Loss = 4.7284584
# Training Observation #340: Loss = 3.7820944e-05
# Training Observation #350: Loss = 2.0497235e-07
# Training Observation #360: Loss = 0.00026308553
# Training Observation #370: Loss = 1.009388e-05
# Training Observation #380: Loss = 1.3812825e-05
# Training Observation #390: Loss = 0.00015433952
# Training Observation #400: Loss = 4.5013303e-06
# Training Observation #410: Loss = 0.24576727
# Training Observation #420: Loss = 1.571462e-05
# Training Observation #430: Loss = 4.060529
# Training Observation #440: Loss = 8.099962
# Training Observation #450: Loss = 0.0014945728
# Training Observation #460: Loss = 3.9768803
# Training Observation #470: Loss = 0.007060628
# Training Observation #480: Loss = 0.88167584
# Training Observation #490: Loss = 0.00038027583
# Training Observation #500: Loss = 0.019783255
# Training Observation #510: Loss = 6.463408
# Training Observation #520: Loss = 0.78394246
# Training Observation #530: Loss = 0.0072938944
# Training Observation #540: Loss = 2.985163e-05
# Training Observation #550: Loss = 1.9225592e-05
# Training Observation #560: Loss = 6.491398e-05
# Training Observation #570: Loss = 0.000751511
# Training Observation #580: Loss = 8.40063e-05
# Training Observation #590: Loss = 0.0005528777
# Training Observation #600: Loss = 0.0028019068
# Training Observation #610: Loss = 0.17804004
# Training Observation #620: Loss = 0.000622748
# Training Observation #630: Loss = 0.00050344935
# Training Observation #640: Loss = 0.00033855607
# Training Observation #650: Loss = 2.1003858e-05
# Training Observation #660: Loss = 0.25261965
# Training Observation #670: Loss = 3.5370027e-05
# Training Observation #680: Loss = 0.000221638
# Training Observation #690: Loss = 2.0060675e-06
# Training Observation #700: Loss = 0.0020576718
# Training Observation #710: Loss = 0.023924347
# Training Observation #720: Loss = 0.0027584194
# Training Observation #730: Loss = 0.5728864
# Training Observation #740: Loss = 0.1281284
# Training Observation #750: Loss = 0.0007793765
# Training Observation #760: Loss = 0.007518784
# Training Observation #770: Loss = 9.523311e-05
# Training Observation #780: Loss = 1.4413927
# Training Observation #790: Loss = 6.4361906
# Training Observation #800: Loss = 0.0013172827
# Training Observation #810: Loss = 8.729217e-06
# Training Observation #820: Loss = 0.0016472049
# Training Observation #830: Loss = 0.00027220722
# Training Observation #840: Loss = 0.01200143
# Training Observation #850: Loss = 4.505131
# Training Observation #860: Loss = 0.00355413
# Training Observation #870: Loss = 0.064876065
# Training Observation #880: Loss = 0.015901253
# Training Observation #890: Loss = 6.186882
# Training Observation #900: Loss = 0.0020539789
# Training Observation #910: Loss = 3.5619905e-05
# Training Observation #920: Loss = 4.159527
# Training Observation #930: Loss = 0.0005493494
# Training Observation #940: Loss = 11.8263445
# Training Observation #950: Loss = 0.000303357
# Training Observation #960: Loss = 0.0047247913
# Training Observation #970: Loss = 6.075516
# Training Observation #980: Loss = 0.52505237
# Training Observation #990: Loss = 0.00421447
# Training Observation #1000: Loss = 11.291561
# Training Observation #1010: Loss = 0.001189355
# Training Observation #1020: Loss = 0.0009186745
# Training Observation #1030: Loss = 0.14154044
# Training Observation #1040: Loss = 0.016069321
# Training Observation #1050: Loss = 0.0011653441
# Training Observation #1060: Loss = 2.999296
# Training Observation #1070: Loss = 0.007031844
# Training Observation #1080: Loss = 0.00013623787
# Training Observation #1090: Loss = 0.7481328
# Training Observation #1100: Loss = 0.0024053953
# Training Observation #1110: Loss = 0.0023857881
# Training Observation #1120: Loss = 0.00018261017
# Training Observation #1130: Loss = 8.266485e-05
# Training Observation #1140: Loss = 8.742717e-05
# Training Observation #1150: Loss = 0.08485666
# Training Observation #1160: Loss = 0.42997894
# Training Observation #1170: Loss = 0.005761885
# Training Observation #1180: Loss = 4.533004
# Training Observation #1190: Loss = 0.00010062115
# Training Observation #1200: Loss = 5.0412135
# Training Observation #1210: Loss = 0.00514052
# Training Observation #1220: Loss = 5.1779607e-05
# Training Observation #1230: Loss = 0.00026935077
# Training Observation #1240: Loss = 0.0009633041
# Training Observation #1250: Loss = 0.016361237
# Training Observation #1260: Loss = 7.005789e-05
# Training Observation #1270: Loss = 0.0008959076
# Training Observation #1280: Loss = 0.008975918
# Training Observation #1290: Loss = 0.069798514
# Training Observation #1300: Loss = 2.5421395
# Training Observation #1310: Loss = 0.0017017875
# Training Observation #1320: Loss = 0.50279516
# Training Observation #1330: Loss = 6.3325906
# Training Observation #1340: Loss = 9.4682e-05
# Training Observation #1350: Loss = 0.002504217
# Training Observation #1360: Loss = 7.361406
# Training Observation #1370: Loss = 2.2396483e-05
# Training Observation #1380: Loss = 1.8751416
# Training Observation #1390: Loss = 8.046688
# Training Observation #1400: Loss = 0.0002793618
# Training Observation #1410: Loss = 0.037287533
# Training Observation #1420: Loss = 0.0032144818
# Training Observation #1430: Loss = 0.09851575
# Training Observation #1440: Loss = 5.3094765e-05
# Training Observation #1450: Loss = 0.0001678322
# Training Observation #1460: Loss = 0.096742764
# Training Observation #1470: Loss = 6.6544166
# Training Observation #1480: Loss = 0.0023271937
# Training Observation #1490: Loss = 0.016550757
# Training Observation #1500: Loss = 0.0002753921
# Training Observation #1510: Loss = 0.12709126
# Training Observation #1520: Loss = 4.2557635
# Training Observation #1530: Loss = 0.002150275
# Training Observation #1540: Loss = 0.00020433738
# Training Observation #1550: Loss = 0.0018811246
# Training Observation #1560: Loss = 6.603427e-06
# Training Observation #1570: Loss = 0.035800215
# Training Observation #1580: Loss = 0.052033417
# Training Observation #1590: Loss = 0.0010106921
# Training Observation #1600: Loss = 5.57289e-05
# Training Observation #1610: Loss = 4.777114
# Training Observation #1620: Loss = 0.040940225
# Training Observation #1630: Loss = 6.2289643
# Training Observation #1640: Loss = 0.00024641375
# Training Observation #1650: Loss = 0.00081982755
# Training Observation #1660: Loss = 7.357896e-05
# Training Observation #1670: Loss = 6.984193
# Training Observation #1680: Loss = 3.4265973e-05
# Training Observation #1690: Loss = 0.021531375
# Training Observation #1700: Loss = 0.00018017783
# Training Observation #1710: Loss = 0.020908467
# Training Observation #1720: Loss = 0.0002890723
# Training Observation #1730: Loss = 0.000100084566
# Training Observation #1740: Loss = 4.995908
# Training Observation #1750: Loss = 0.012757048
# Training Observation #1760: Loss = 0.0010308964
# Training Observation #1770: Loss = 0.008160471
# Training Observation #1780: Loss = 11.930662
# Training Observation #1790: Loss = 3.5881493
# Training Observation #1800: Loss = 0.0007430287
# Training Observation #1810: Loss = 0.5418766
# Training Observation #1820: Loss = 6.33848
# Training Observation #1830: Loss = 0.0002360716
# Training Observation #1840: Loss = 0.0027689713
# Training Observation #1850: Loss = 5.53184
# Training Observation #1860: Loss = 0.0061402707
# Training Observation #1870: Loss = 0.008889308
# Training Observation #1880: Loss = 0.0008051985
# Training Observation #1890: Loss = 0.033674285
# Training Observation #1900: Loss = 0.027510194
# Training Observation #1910: Loss = 0.37084186
# Training Observation #1920: Loss = 0.00012361667
# Training Observation #1930: Loss = 0.25993645
# Training Observation #1940: Loss = 0.19941978
# Training Observation #1950: Loss = 0.007857151
# Training Observation #1960: Loss = 0.0028452144
# Training Observation #1970: Loss = 0.20498066
# Training Observation #1980: Loss = 0.0013183578
# Training Observation #1990: Loss = 0.2830133
# Training Observation #2000: Loss = 0.0035226964
# Training Observation #2010: Loss = 0.0042119417
# Training Observation #2020: Loss = 0.00028169755
# Training Observation #2030: Loss = 0.00014747499
# Training Observation #2040: Loss = 0.4861156
# Training Observation #2050: Loss = 1.7038531
# Training Observation #2060: Loss = 1.2930709
# Training Observation #2070: Loss = 0.00010425604
# Training Observation #2080: Loss = 0.015276423
# Training Observation #2090: Loss = 0.00011156662
# Training Observation #2100: Loss = 0.004408156
# Training Observation #2110: Loss = 0.0023772994
# Training Observation #2120: Loss = 0.00019007314
# Training Observation #2130: Loss = 0.0008015828
# Training Observation #2140: Loss = 0.0005474449
# Training Observation #2150: Loss = 8.325505
# Training Observation #2160: Loss = 3.6825545
# Training Observation #2170: Loss = 12.43043
# Training Observation #2180: Loss = 1.0361689
# Training Observation #2190: Loss = 0.19762261
# Training Observation #2200: Loss = 5.049435
# Training Observation #2210: Loss = 0.0035870073
# Training Observation #2220: Loss = 0.0002704866
# Training Observation #2230: Loss = 0.008370103
# Training Observation #2240: Loss = 5.4937634
# Training Observation #2250: Loss = 1.6654327
# Training Observation #2260: Loss = 5.110379
# Training Observation #2270: Loss = 0.056707513
# Training Observation #2280: Loss = 0.011914031
# Training Observation #2290: Loss = 0.0018329064
# Training Observation #2300: Loss = 0.15163967
# Training Observation #2310: Loss = 0.18138297
# Training Observation #2320: Loss = 0.016479215
# Training Observation #2330: Loss = 0.17112646
# Training Observation #2340: Loss = 7.172767
# Training Observation #2350: Loss = 0.00036496788
# Training Observation #2360: Loss = 0.43049014
# Training Observation #2370: Loss = 0.00037450076
# Training Observation #2380: Loss = 5.1437554
# Training Observation #2390: Loss = 2.1314743
# Training Observation #2400: Loss = 0.004827936
# Training Observation #2410: Loss = 0.000106552034
# Training Observation #2420: Loss = 0.00093294133
# Training Observation #2430: Loss = 0.03745905
# Training Observation #2440: Loss = 0.00067324453
# Training Observation #2450: Loss = 0.015604768
# Training Observation #2460: Loss = 4.593522e-05
# Training Observation #2470: Loss = 0.0053975224
# Training Observation #2480: Loss = 0.95566064
# Training Observation #2490: Loss = 0.0014060894
# Training Observation #2500: Loss = 3.5850968
# Training Observation #2510: Loss = 0.00012511453
# Training Observation #2520: Loss = 0.022426855
# Training Observation #2530: Loss = 0.20692979
# Training Observation #2540: Loss = 6.162185
# Training Observation #2550: Loss = 8.77846
# Training Observation #2560: Loss = 0.00014420686
# Training Observation #2570: Loss = 0.0011184994
# Training Observation #2580: Loss = 8.3915416e-05
# Training Observation #2590: Loss = 2.8253105
# Training Observation #2600: Loss = 0.75098777
# Training Observation #2610: Loss = 0.00012574704
# Training Observation #2620: Loss = 0.0017163389
# Training Observation #2630: Loss = 3.0009987
# Training Observation #2640: Loss = 2.573665
# Training Observation #2650: Loss = 1.3085816
# Training Observation #2660: Loss = 0.014309757
# Training Observation #2670: Loss = 3.7527993e-06
# Training Observation #2680: Loss = 0.0019564743
# Training Observation #2690: Loss = 1.0387688
# Training Observation #2700: Loss = 1.089564
# Training Observation #2710: Loss = 0.020882072
# Training Observation #2720: Loss = 2.7762055e-06
# Training Observation #2730: Loss = 0.00011759801
# Training Observation #2740: Loss = 0.0025069076
# Training Observation #2750: Loss = 3.2306855e-06
# Training Observation #2760: Loss = 0.00043736835
# Training Observation #2770: Loss = 0.0009113621
# Training Observation #2780: Loss = 6.179262
# Training Observation #2790: Loss = 10.788313
# Training Observation #2800: Loss = 0.00012905432
# Training Observation #2810: Loss = 0.020631978
# Training Observation #2820: Loss = 1.9537643e-05
# Training Observation #2830: Loss = 0.009231418
# Training Observation #2840: Loss = 0.6243442
# Training Observation #2850: Loss = 0.36753228
# Training Observation #2860: Loss = 0.00048229087
# Training Observation #2870: Loss = 0.01987171
# Training Observation #2880: Loss = 3.7266002e-06
# Training Observation #2890: Loss = 0.000904555
# Training Observation #2900: Loss = 0.00070932024
# Training Observation #2910: Loss = 8.110353e-05
# Training Observation #2920: Loss = 0.0008359693
# Training Observation #2930: Loss = 0.006206526
# Training Observation #2940: Loss = 7.205053e-05
# Training Observation #2950: Loss = 0.00014291589
# Training Observation #2960: Loss = 0.009750917
# Training Observation #2970: Loss = 0.17404687
# Training Observation #2980: Loss = 3.883912e-05
# Training Observation #2990: Loss = 0.0053842193
# Training Observation #3000: Loss = 6.1878727e-06
# Training Observation #3010: Loss = 0.001010418
# Training Observation #3020: Loss = 0.009948861
# Training Observation #3030: Loss = 10.13789
# Training Observation #3040: Loss = 3.519966e-05
# Training Observation #3050: Loss = 0.0007397542
# Training Observation #3060: Loss = 0.008698809
# Training Observation #3070: Loss = 0.019117296
# Training Observation #3080: Loss = 0.19894089
# Training Observation #3090: Loss = 0.003939484
# Training Observation #3100: Loss = 0.0020418463
# Training Observation #3110: Loss = 0.28228015
# Training Observation #3120: Loss = 0.16856763
# Training Observation #3130: Loss = 1.3638036
# Training Observation #3140: Loss = 5.0043726
# Training Observation #3150: Loss = 0.00012650802
# Training Observation #3160: Loss = 5.3501786e-05
# Training Observation #3170: Loss = 0.008886527
# Training Observation #3180: Loss = 4.907598
# Training Observation #3190: Loss = 0.19087572
# Training Observation #3200: Loss = 0.00027004746
# Training Observation #3210: Loss = 0.006369196
# Training Observation #3220: Loss = 0.0019805776
# Training Observation #3230: Loss = 0.010723597
# Training Observation #3240: Loss = 0.0031419203
# Training Observation #3250: Loss = 0.0112273
# Training Observation #3260: Loss = 0.0062265587
# Training Observation #3270: Loss = 1.3848155
# Training Observation #3280: Loss = 0.0062108967
# Training Observation #3290: Loss = 0.0014131838
# Training Observation #3300: Loss = 0.72521657
# Training Observation #3310: Loss = 1.4654596
# Training Observation #3320: Loss = 0.0062653543
# Training Observation #3330: Loss = 0.83492184
# Training Observation #3340: Loss = 11.256589
# Training Observation #3350: Loss = 0.027747577
# Training Observation #3360: Loss = 0.02206676
# Training Observation #3370: Loss = 1.3040205
# Training Observation #3380: Loss = 0.005013822
# Training Observation #3390: Loss = 0.0066472837
# Training Observation #3400: Loss = 0.00028912682
# Training Observation #3410: Loss = 0.0064900643
# Training Observation #3420: Loss = 0.00016373064
# Training Observation #3430: Loss = 0.0001219304
# Training Observation #3440: Loss = 0.00092473463
# Training Observation #3450: Loss = 2.053326
# Training Observation #3460: Loss = 0.11240153
# Training Observation #3470: Loss = 0.013661346
# Training Observation #3480: Loss = 0.29954246
# Training Observation #3490: Loss = 2.7893326e-05
# Training Observation #3500: Loss = 0.006022855
# Training Observation #3510: Loss = 3.5136514
# Training Observation #3520: Loss = 3.0931935
# Training Observation #3530: Loss = 8.355595
# Training Observation #3540: Loss = 0.00196528
# Training Observation #3550: Loss = 1.1100221
# Training Observation #3560: Loss = 0.000555321
# Training Observation #3570: Loss = 0.0024286443
# Training Observation #3580: Loss = 0.087877914
# Training Observation #3590: Loss = 0.00044040658
# Training Observation #3600: Loss = 0.0022573425
# Training Observation #3610: Loss = 10.033028
# Training Observation #3620: Loss = 0.0113581475
# Training Observation #3630: Loss = 0.12879567
# Training Observation #3640: Loss = 3.8448083
# Training Observation #3650: Loss = 0.004120129
# Training Observation #3660: Loss = 0.044461668
# Training Observation #3670: Loss = 5.2682743
# Training Observation #3680: Loss = 0.00012630527
# Training Observation #3690: Loss = 0.23965144
# Training Observation #3700: Loss = 0.00015067642
# Training Observation #3710: Loss = 0.044670854
# Training Observation #3720: Loss = 0.00078463845
# Training Observation #3730: Loss = 0.47579277
# Training Observation #3740: Loss = 0.0005006164
# Training Observation #3750: Loss = 0.59615946
# Training Observation #3760: Loss = 0.006196512
# Training Observation #3770: Loss = 0.00049499713
# Training Observation #3780: Loss = 0.0811437
# Training Observation #3790: Loss = 0.3466481
# Training Observation #3800: Loss = 0.00038600358
# Training Observation #3810: Loss = 0.057205375
# Training Observation #3820: Loss = 3.3428705
# Training Observation #3830: Loss = 3.5661027
# Training Observation #3840: Loss = 0.38231438
# Training Observation #3850: Loss = 0.00017226698
# Training Observation #3860: Loss = 0.0015815678
# Training Observation #3870: Loss = 0.0009105151
# Training Observation #3880: Loss = 0.0005010715
# Training Observation #3890: Loss = 0.003255321
# Training Observation #3900: Loss = 0.00020006286
# Training Observation #3910: Loss = 2.6045377
# Training Observation #3920: Loss = 0.010568243
# Training Observation #3930: Loss = 8.1843886e-05
# Training Observation #3940: Loss = 0.008921013
# Training Observation #3950: Loss = 0.0021248425
# Training Observation #3960: Loss = 0.005099929
# Training Observation #3970: Loss = 0.001310397
# Training Observation #3980: Loss = 4.6678643
# Training Observation #3990: Loss = 0.000992482
# Training Observation #4000: Loss = 0.002819235
# Training Observation #4010: Loss = 0.08579478
# Training Observation #4020: Loss = 0.02265082
# Training Observation #4030: Loss = 0.057168126
# Training Observation #4040: Loss = 5.0681396
# Training Observation #4050: Loss = 0.9589579
# Training Observation #4060: Loss = 0.15208796
# Training Observation #4070: Loss = 0.0031889232
# Training Observation #4080: Loss = 10.382889
# Training Observation #4090: Loss = 0.001598246
# Training Observation #4100: Loss = 1.8790268
# Training Observation #4110: Loss = 0.06224103
# Training Observation #4120: Loss = 1.9823976
# Training Observation #4130: Loss = 0.06279414
# Training Observation #4140: Loss = 0.00689788
# Training Observation #4150: Loss = 0.022106322
# Training Observation #4160: Loss = 0.0056367647
# Training Observation #4170: Loss = 0.012385452
# Training Observation #4180: Loss = 0.23038793
# Training Observation #4190: Loss = 0.00028498858
# Training Observation #4200: Loss = 0.05907873
# Training Observation #4210: Loss = 0.0035525635
# Training Observation #4220: Loss = 1.4674188
# Training Observation #4230: Loss = 0.0023327768
# Training Observation #4240: Loss = 0.0035543514
# Training Observation #4250: Loss = 0.0008788976
# Training Observation #4260: Loss = 0.11144147
# Training Observation #4270: Loss = 0.000103498234
# Training Observation #4280: Loss = 5.970538
# Training Observation #4290: Loss = 0.174119
# Training Observation #4300: Loss = 0.002802965
# Training Observation #4310: Loss = 0.0068748756
# Training Observation #4320: Loss = 0.00031487297
# Training Observation #4330: Loss = 0.011633933
# Training Observation #4340: Loss = 0.00849083
# Training Observation #4350: Loss = 0.00040164188
# Training Observation #4360: Loss = 0.019674608
# Training Observation #4370: Loss = 0.00015086216
# Training Observation #4380: Loss = 0.005694753
# Training Observation #4390: Loss = 0.1316328
# Training Observation #4400: Loss = 0.0015156423
# Training Observation #4410: Loss = 0.022822144
# Training Observation #4420: Loss = 3.998151
# Training Observation #4430: Loss = 1.9665824e-05
# Training Observation #4440: Loss = 0.005446807
# Training Observation #4450: Loss = 2.0961596e-05

# %% [markdown]
# Now that we have a logistic model, we can evaluate the accuracy on the test dataset.

# %%
# Get test set accuracy
print('Getting Test Set Accuracy For {} Sentences.'.format(len(texts_test)))
test_acc_all = []
for ix, t in enumerate(vocab_processor.fit_transform(texts_test)):
    y_data = [[target_test[ix]]]
    
    if (ix+1)%50==0:
        print('Test Observation #' + str(ix+1))    
    
    # Keep trailing average of past 50 observations accuracy
    # Get prediction of single observation
    [[temp_pred]] = sess.run(prediction, feed_dict={x_data:t, y_target:y_data})
    # Get True/False if prediction is accurate
    test_acc_temp = target_test[ix]==np.round(temp_pred)
    test_acc_all.append(test_acc_temp)

print('\nOverall Test Accuracy: {}'.format(np.mean(test_acc_all)))
# Out:
# Getting Test Set Accuracy For 1115 Sentences.
# Test Observation #50
# Test Observation #100
# Test Observation #150
# Test Observation #200
# Test Observation #250
# Test Observation #300
# Test Observation #350
# Test Observation #400
# Test Observation #450
# Test Observation #500
# Test Observation #550
# Test Observation #600
# Test Observation #650
# Test Observation #700
# Test Observation #750
# Test Observation #800
# Test Observation #850
# Test Observation #900
# Test Observation #950
# Test Observation #1000
# Test Observation #1050
# Test Observation #1100
#
# Overall Test Accuracy: 0.8170403587443946

# %% [markdown]
# Let's look at the training accuracy over all the iterations.

# %%
# %matplotlib inline
# Plot training accuracy over time
plt.plot(range(len(train_acc_avg)), train_acc_avg, 'k-', label='Train Accuracy')
plt.title('Avg Training Acc Over Past 50 Iterations')
plt.xlabel('Iterations')
plt.ylabel('Training Accuracy')
plt.show()

# %% [markdown]
# It is worthwhile to mention the motivation of limiting the sentence (or text) size. In this example we limited the text size to 25 words. This is a common practice with bag of words because it limits the effect of text length on the prediction. You can imagine that if we find a word, “meeting” for example, that is predictive of a text being ham (not spam), then a spam message might get through by putting in many occurrences of that word at the end. In fact, this is a common problem with imbalanced target data. Imbalanced data might occur in this situation, since spam may be hard to find and ham may be easy to find. Because of this fact, our vocabulary that we create might be heavily skewed toward words represented in the ham part of our data (more ham means more words are represented in ham than spam). If we allow unlimited length of texts, then spammers might take advantage of this and create very long texts, which have a higher probability of triggering non-spam word factors in our logistic model.
