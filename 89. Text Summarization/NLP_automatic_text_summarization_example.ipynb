# %% [markdown]
# # 0. Introduction

# %% [markdown]
# This is a simple abstractive text summarization model that is based on the sequence-to-sequence with attention model. The original code is based on Pan and Liu's model from ["Sequence-to-Sequence with Attention Model for Text Summarization"](https://github.com/weichengzhang/Summarization), and simplified by [Currie](https://github.com/Currie32/Text-Summarization-with-Amazon-Reviews/blob/master/summarize_reviews.ipynb). The model was trained on [amazon's product reviews](https://www.kaggle.com/snap/amazon-fine-food-reviews). The original dataset is too large and will take a few days to train the model on a local environment only using CPU, so the training set only used a part of the dataset.
#
# For comparison, we will use the same text and summarize using a library called [sumy](https://github.com/miso-belica/sumy), which has multiple automatic summarization methods. We will use a TextRank method to automatically summarize text by extracting sentences that are deemed important.

# %% [markdown]
# # 1. Importing and cleaning data

# %%
# libraries
import pandas as pd
import numpy as np
import tensorflow as tf
import re
from nltk.corpus import stopwords
import time
from tensorflow.python.layers.core import Dense
from tensorflow.python.ops.rnn_cell_impl import _zero_state_tensors

# %%
df = pd.read_csv("Reviews.csv")

# %%
print(df.shape)
df.head(2)
# Out:
# (568454, 10)
#    Id   ProductId          UserId ProfileName  HelpfulnessNumerator  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW  delmartian                     1
# 1   2  B00813GRG4  A1D87F6ZCVE5NK      dll pa                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...

# %%
# null values
df.isnull().sum()
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName               16
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64

# %%
# remove null values and unneeded featured
df = df.dropna()
df = df[['Summary','Text']]

# %%
# view some reviews
for i in range(2):
    print('Review {}:'.format(i+1))
    print(df.loc[i,'Summary'])
    print(df.loc[i,'Text'])
    print()
# Out:
# Review 1:
# Good Quality Dog Food
# I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.
#
# Review 2:
# Not as Advertised
# Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".

# %% [markdown]
# # 2. Preparing data for training

# %%
# A list of contractions from http://stackoverflow.com/questions/19790188/expanding-english-language-contractions-in-python
contractions = { 
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he's": "he is",
"how'd": "how did",
"how'll": "how will",
"how's": "how is",
"i'd": "i would",
"i'll": "i will",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'll": "it will",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"must've": "must have",
"mustn't": "must not",
"needn't": "need not",
"oughtn't": "ought not",
"shan't": "shall not",
"sha'n't": "shall not",
"she'd": "she would",
"she'll": "she will",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"that'd": "that would",
"that's": "that is",
"there'd": "there had",
"there's": "there is",
"they'd": "they would",
"they'll": "they will",
"they're": "they are",
"they've": "they have",
"wasn't": "was not",
"we'd": "we would",
"we'll": "we will",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"where'd": "where did",
"where's": "where is",
"who'll": "who will",
"who's": "who is",
"won't": "will not",
"wouldn't": "would not",
"you'd": "you would",
"you'll": "you will",
"you're": "you are"
}

# %%
# create function that cleans text
def clean_text(text, remove_stopwords = True):
    '''Remove unwanted characters, stopwords, and format the text to create fewer nulls word embeddings'''
    
    # Convert words to lower case
    text = text.lower()
    
    # Replace contractions with their longer forms 
    if True:
        text = text.split()
        new_text = []
        for word in text:
            if word in contractions:
                new_text.append(contractions[word])
            else:
                new_text.append(word)
        text = " ".join(new_text)
    
    # Format words and remove unwanted characters
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
    text = re.sub(r'\<a href', ' ', text)
    text = re.sub(r'&amp;', '', text) 
    text = re.sub(r'[_"\-;%()|+&=*%.,!?:#$@\[\]/]', ' ', text)
    text = re.sub(r'<br />', ' ', text)
    text = re.sub(r'\'', ' ', text)
    
    # Optionally, remove stop words
    if remove_stopwords:
        text = text.split()
        stops = set(stopwords.words("english"))
        text = [w for w in text if not w in stops]
        text = " ".join(text)

    return text

# %%
# remove stopwords from texts for training purposes,
# but keep them in summary to result in more coherent summary

# Clean the summaries and texts
clean_summaries = []
for summary in df.Summary:
    clean_summaries.append(clean_text(summary, remove_stopwords=False))
print("Summaries are complete.")

clean_texts = []
for text in df.Text:
    clean_texts.append(clean_text(text))
print("Texts are complete.")
# Out:
# Summaries are complete.
# Texts are complete.

# %%
# Find the number of times each word was used and the size of the vocabulary
def count_words(count_dict, text):
    '''Count the number of occurrences of each word in a set of text'''
    for sentence in text:
        for word in sentence.split():
            if word not in count_dict:
                count_dict[word] = 1
            else:
                count_dict[word] += 1

word_counts = {}

count_words(word_counts, clean_summaries)
count_words(word_counts, clean_texts)
            
print("Size of Vocabulary:", len(word_counts))
# Out:
# Size of Vocabulary: 132884

# %%
# Load Conceptnet Numberbatch's (CN) embeddings, similar to GloVe, but probably better 
# (https://github.com/commonsense/conceptnet-numberbatch)
embeddings_index = {}
with open('numberbatch-en-17.06.txt', encoding='utf-8') as f:
    for line in f:
        values = line.split(' ')
        word = values[0]
        embedding = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = embedding

print('Word embeddings:', len(embeddings_index))
# Out:
# Word embeddings: 417195

# %%
# Find the number of words that are missing from CN, and are used more than our threshold.
missing_words = 0
threshold = 20

for word, count in word_counts.items():
    if count > threshold:
        if word not in embeddings_index:
            missing_words += 1
            
missing_ratio = round(missing_words/len(word_counts),4)*100
            
print("Number of words missing from CN:", missing_words)
print("Percent of words that are missing from vocabulary: {}%".format(missing_ratio))
# Out:
# Number of words missing from CN: 3870
# Percent of words that are missing from vocabulary: 2.91%

# %%
# Limit the vocab that we will use to words that appear ≥ threshold or are in GloVe

#dictionary to convert words to integers
vocab_to_int = {} 

value = 0
for word, count in word_counts.items():
    if count >= threshold or word in embeddings_index:
        vocab_to_int[word] = value
        value += 1

# Special tokens that will be added to our vocab
codes = ["<UNK>","<PAD>","<EOS>","<GO>"]   

# Add codes to vocab
for code in codes:
    vocab_to_int[code] = len(vocab_to_int)

# Dictionary to convert integers to words
int_to_vocab = {}
for word, value in vocab_to_int.items():
    int_to_vocab[value] = word

usage_ratio = round(len(vocab_to_int) / len(word_counts),4)*100

print("Total number of unique words:", len(word_counts))
print("Number of words we will use:", len(vocab_to_int))
print("Percent of words we will use: {}%".format(usage_ratio))
# Out:
# Total number of unique words: 132884
# Number of words we will use: 59595
# Percent of words we will use: 44.85%

# %%
# Need to use 300 for embedding dimensions to match CN's vectors.
embedding_dim = 300
nb_words = len(vocab_to_int)

# Create matrix with default values of zero
word_embedding_matrix = np.zeros((nb_words, embedding_dim), dtype=np.float32)
for word, i in vocab_to_int.items():
    if word in embeddings_index:
        word_embedding_matrix[i] = embeddings_index[word]
    else:
        # If word not in CN, create a random embedding for it
        new_embedding = np.array(np.random.uniform(-1.0, 1.0, embedding_dim))
        embeddings_index[word] = new_embedding
        word_embedding_matrix[i] = new_embedding

# Check if value matches len(vocab_to_int)
print(len(word_embedding_matrix))
# Out:
# 59595

# %%
def convert_to_ints(text, word_count, unk_count, eos=False):
    '''Convert words in text to an integer.
       If word is not in vocab_to_int, use UNK's integer.
       Total the number of words and UNKs.
       Add EOS token to the end of texts'''
    ints = []
    for sentence in text:
        sentence_ints = []
        for word in sentence.split():
            word_count += 1
            if word in vocab_to_int:
                sentence_ints.append(vocab_to_int[word])
            else:
                sentence_ints.append(vocab_to_int["<UNK>"])
                unk_count += 1
        if eos:
            sentence_ints.append(vocab_to_int["<EOS>"])
        ints.append(sentence_ints)
    return ints, word_count, unk_count

# %%
# Apply convert_to_ints to clean_summaries and clean_texts
word_count = 0
unk_count = 0

int_summaries, word_count, unk_count = convert_to_ints(clean_summaries, word_count, unk_count)
int_texts, word_count, unk_count = convert_to_ints(clean_texts, word_count, unk_count, eos=True)

unk_percent = round(unk_count/word_count,4)*100

print("Total number of words in headlines:", word_count)
print("Total number of UNKs in headlines:", unk_count)
print("Percent of words that are UNK: {}%".format(unk_percent))
# Out:
# Total number of words in headlines: 25679933
# Total number of UNKs in headlines: 192245
# Percent of words that are UNK: 0.75%

# %%
def create_lengths(text):
    '''Create a data frame of the sentence lengths from a text'''
    lengths = []
    for sentence in text:
        lengths.append(len(sentence))
    return pd.DataFrame(lengths, columns=['counts'])

lengths_summaries = create_lengths(int_summaries)
lengths_texts = create_lengths(int_texts)

print("Summaries:")
print(lengths_summaries.describe())
print()
print("Texts:")
print(lengths_texts.describe())
# Out:
# Summaries:
#               counts
# count  568411.000000
# mean        4.181624
# std         2.657872
# min         0.000000
# 25%         2.000000
# 50%         4.000000
# 75%         5.000000
# max        48.000000
#
# Texts:
#               counts
# count  568411.000000
# mean       41.996835
# std        42.520873
# min         1.000000
# 25%        18.000000
# 50%        29.000000
# 75%        50.000000
# max      2085.000000

# %%
def unk_counter(sentence):
    '''Counts the number of time UNK appears in a sentence.'''
    unk_count = 0
    for word in sentence:
        if word == vocab_to_int["<UNK>"]:
            unk_count += 1
    return unk_count

# Sort the summaries and texts by the length of the texts, shortest to longest
# Limit the length of summaries and texts based on the min and max ranges.
# Remove reviews that include too many UNKs

sorted_summaries = []
sorted_texts = []
max_text_length = 84
max_summary_length = 13
min_length = 2
unk_text_limit = 1
unk_summary_limit = 0

for length in range(min(lengths_texts.counts), max_text_length): 
    for count, words in enumerate(int_summaries):
        if (len(int_summaries[count]) >= min_length and
            len(int_summaries[count]) <= max_summary_length and
            len(int_texts[count]) >= min_length and
            unk_counter(int_summaries[count]) <= unk_summary_limit and
            unk_counter(int_texts[count]) <= unk_text_limit and
            length == len(int_texts[count])
           ):
            sorted_summaries.append(int_summaries[count])
            sorted_texts.append(int_texts[count])
        
# Compare lengths to ensure they match
print(len(sorted_summaries))
print(len(sorted_texts))
# Out:
# 425615
# 425615

# %% [markdown]
# # 3. Building seq2seq with attention model

# %%
def model_inputs():
    '''Create palceholders for inputs to the model'''
    
    input_data = tf.placeholder(tf.int32, [None, None], name='input')
    targets = tf.placeholder(tf.int32, [None, None], name='targets')
    lr = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    summary_length = tf.placeholder(tf.int32, (None,), name='summary_length')
    max_summary_length = tf.reduce_max(summary_length, name='max_dec_len')
    text_length = tf.placeholder(tf.int32, (None,), name='text_length')

    return input_data, targets, lr, keep_prob, summary_length, max_summary_length, text_length

# %%
def process_encoding_input(target_data, vocab_to_int, batch_size):
    '''Remove the last word id from each batch and concat the <GO> to the begining of each batch'''
    
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], vocab_to_int['<GO>']), ending], 1)

    return dec_input

# %%
def encoding_layer(rnn_size, sequence_length, num_layers, rnn_inputs, keep_prob):
    '''Create the encoding layer'''
    
    for layer in range(num_layers):
        with tf.variable_scope('encoder_{}'.format(layer)):
            cell_fw = tf.contrib.rnn.LSTMCell(rnn_size,
                                              initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
            cell_fw = tf.contrib.rnn.DropoutWrapper(cell_fw, 
                                                    input_keep_prob = keep_prob)

            cell_bw = tf.contrib.rnn.LSTMCell(rnn_size,
                                              initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
            cell_bw = tf.contrib.rnn.DropoutWrapper(cell_bw, 
                                                    input_keep_prob = keep_prob)

            enc_output, enc_state = tf.nn.bidirectional_dynamic_rnn(cell_fw, 
                                                                    cell_bw, 
                                                                    rnn_inputs,
                                                                    sequence_length,
                                                                    dtype=tf.float32)
    # Join outputs since we are using a bidirectional RNN
    enc_output = tf.concat(enc_output,2)
    
    return enc_output, enc_state

# %%
def training_decoding_layer(dec_embed_input, summary_length, dec_cell, initial_state, output_layer, 
                            vocab_size, max_summary_length):
    '''Create the training logits'''
    
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input,
                                                        sequence_length=summary_length,
                                                        time_major=False)

    training_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                       training_helper,
                                                       initial_state,
                                                       output_layer) 

    training_logits, _ = tf.contrib.seq2seq.dynamic_decode(training_decoder,
                                                           output_time_major=False,
                                                           impute_finished=True,
                                                           maximum_iterations=max_summary_length)
    return training_logits

# %%
def inference_decoding_layer(embeddings, start_token, end_token, dec_cell, initial_state, output_layer,
                             max_summary_length, batch_size):
    '''Create the inference logits'''
    
    start_tokens = tf.tile(tf.constant([start_token], dtype=tf.int32), [batch_size], name='start_tokens')
    
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(embeddings,
                                                                start_tokens,
                                                                end_token)
                
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                        inference_helper,
                                                        initial_state,
                                                        output_layer)
                
    inference_logits, _ = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                            output_time_major=False,
                                                            impute_finished=True,
                                                            maximum_iterations=max_summary_length)
    
    return inference_logits

# %%
def decoding_layer(dec_embed_input, embeddings, enc_output, enc_state, vocab_size, text_length, summary_length, 
                   max_summary_length, rnn_size, vocab_to_int, keep_prob, batch_size, num_layers):
    '''Create the decoding cell and attention for the training and inference decoding layers'''
    
    for layer in range(num_layers):
        with tf.variable_scope('decoder_{}'.format(layer)):
            lstm = tf.contrib.rnn.LSTMCell(rnn_size,
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
            dec_cell = tf.contrib.rnn.DropoutWrapper(lstm, 
                                                     input_keep_prob = keep_prob)
    
    output_layer = Dense(vocab_size,
                         kernel_initializer = tf.truncated_normal_initializer(mean = 0.0, stddev=0.1))
    
    attn_mech = tf.contrib.seq2seq.BahdanauAttention(rnn_size,
                                                  enc_output,
                                                  text_length,
                                                  normalize=False,
                                                  name='BahdanauAttention')

    dec_cell = tf.contrib.seq2seq.DynamicAttentionWrapper(dec_cell,
                                                          attn_mech,
                                                          rnn_size)
            
    initial_state = tf.contrib.seq2seq.DynamicAttentionWrapperState(enc_state[0],
                                                                    _zero_state_tensors(rnn_size, 
                                                                                        batch_size, 
                                                                                        tf.float32)) 
    with tf.variable_scope("decode"):
        training_logits = training_decoding_layer(dec_embed_input, 
                                                  summary_length, 
                                                  dec_cell, 
                                                  initial_state,
                                                  output_layer,
                                                  vocab_size, 
                                                  max_summary_length)
    with tf.variable_scope("decode", reuse=True):
        inference_logits = inference_decoding_layer(embeddings,  
                                                    vocab_to_int['<GO>'], 
                                                    vocab_to_int['<EOS>'],
                                                    dec_cell, 
                                                    initial_state, 
                                                    output_layer,
                                                    max_summary_length,
                                                    batch_size)

    return training_logits, inference_logits

# %%
def seq2seq_model(input_data, target_data, keep_prob, text_length, summary_length, max_summary_length, 
                  vocab_size, rnn_size, num_layers, vocab_to_int, batch_size):
    '''Use the previous functions to create the training and inference logits'''
    
    # Use Numberbatch's embeddings and the newly created ones as our embeddings
    embeddings = word_embedding_matrix
    
    enc_embed_input = tf.nn.embedding_lookup(embeddings, input_data)
    enc_output, enc_state = encoding_layer(rnn_size, text_length, num_layers, enc_embed_input, keep_prob)
    
    dec_input = process_encoding_input(target_data, vocab_to_int, batch_size)
    dec_embed_input = tf.nn.embedding_lookup(embeddings, dec_input)
    
    training_logits, inference_logits  = decoding_layer(dec_embed_input, 
                                                        embeddings,
                                                        enc_output,
                                                        enc_state, 
                                                        vocab_size, 
                                                        text_length, 
                                                        summary_length, 
                                                        max_summary_length,
                                                        rnn_size, 
                                                        vocab_to_int, 
                                                        keep_prob, 
                                                        batch_size,
                                                        num_layers)
    
    return training_logits, inference_logits

# %%
def pad_sentence_batch(sentence_batch):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [vocab_to_int['<PAD>']] * (max_sentence - len(sentence)) for sentence in sentence_batch]

# %%
def get_batches(summaries, texts, batch_size):
    """Batch summaries, texts, and the lengths of their sentences together"""
    for batch_i in range(0, len(texts)//batch_size):
        start_i = batch_i * batch_size
        summaries_batch = summaries[start_i:start_i + batch_size]
        texts_batch = texts[start_i:start_i + batch_size]
        pad_summaries_batch = np.array(pad_sentence_batch(summaries_batch))
        pad_texts_batch = np.array(pad_sentence_batch(texts_batch))
        
        # Need the lengths for the _lengths parameters
        pad_summaries_lengths = []
        for summary in pad_summaries_batch:
            pad_summaries_lengths.append(len(summary))
        
        pad_texts_lengths = []
        for text in pad_texts_batch:
            pad_texts_lengths.append(len(text))
        
        yield pad_summaries_batch, pad_texts_batch, pad_summaries_lengths, pad_texts_lengths

# %%
# Set the Hyperparameters
epochs = 100
batch_size = 64
rnn_size = 256
num_layers = 2
learning_rate = 0.005
keep_probability = 0.75

# %%
# Build the graph
train_graph = tf.Graph()
# Set the graph to default to ensure that it is ready for training
with train_graph.as_default():
    
    # Load the model inputs    
    input_data, targets, lr, keep_prob, summary_length, max_summary_length, text_length = model_inputs()

    # Create the training and inference logits
    training_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                      targets, 
                                                      keep_prob,   
                                                      text_length,
                                                      summary_length,
                                                      max_summary_length,
                                                      len(vocab_to_int)+1,
                                                      rnn_size, 
                                                      num_layers, 
                                                      vocab_to_int,
                                                      batch_size)
    
    # Create tensors for the training logits and inference logits
    training_logits = tf.identity(training_logits.rnn_output, 'logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')
    
    # Create the weights for sequence_loss
    masks = tf.sequence_mask(summary_length, max_summary_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(learning_rate)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -5., 5.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)
print("Graph is built.")
# Out:
# /Users/jk6653284/anaconda/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Graph is built.

# %% [markdown]
# # 4. Training the model using training dataset

# %%
# only use subset
# Subset the data for training
start = 200000
end = start + 30000
sorted_summaries_short = sorted_summaries[start:end]
sorted_texts_short = sorted_texts[start:end]
print("The shortest text length:", len(sorted_texts_short[0]))
print("The longest text length:",len(sorted_texts_short[-1]))
# Out:
# The shortest text length: 25
# The longest text length: 29

# %%
# Train the Model
learning_rate_decay = 0.95
min_learning_rate = 0.0005
display_step = 20 # Check training loss after every 20 batches
stop_early = 0 
stop = 3 # If the update loss does not decrease in 3 consecutive update checks, stop training
per_epoch = 3 # Make 3 update checks per epoch
update_check = (len(sorted_texts_short)//batch_size//per_epoch)-1

update_loss = 0 
batch_loss = 0
summary_update_loss = [] # Record the update losses for saving improvements in the model

checkpoint = "best_model.ckpt" 
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())
    
    # If we want to continue training a previous session
    #loader = tf.train.import_meta_graph("./" + checkpoint + '.meta')
    #loader.restore(sess, checkpoint)
    
    for epoch_i in range(1, epochs+1):
        update_loss = 0
        batch_loss = 0
        for batch_i, (summaries_batch, texts_batch, summaries_lengths, texts_lengths) in enumerate(
                get_batches(sorted_summaries_short, sorted_texts_short, batch_size)):
            start_time = time.time()
            _, loss = sess.run(
                [train_op, cost],
                {input_data: texts_batch,
                 targets: summaries_batch,
                 lr: learning_rate,
                 summary_length: summaries_lengths,
                 text_length: texts_lengths,
                 keep_prob: keep_probability})

            batch_loss += loss
            update_loss += loss
            end_time = time.time()
            batch_time = end_time - start_time

            if batch_i % display_step == 0 and batch_i > 0:
                print('Epoch {:>3}/{} Batch {:>4}/{} - Loss: {:>6.3f}, Seconds: {:>4.2f}'
                      .format(epoch_i,
                              epochs, 
                              batch_i, 
                              len(sorted_texts_short) // batch_size, 
                              batch_loss / display_step, 
                              batch_time*display_step))
                batch_loss = 0

            if batch_i % update_check == 0 and batch_i > 0:
                print("Average loss for this update:", round(update_loss/update_check,3))
                summary_update_loss.append(update_loss)
                
                # If the update loss is at a new minimum, save the model
                if update_loss <= min(summary_update_loss):
                    print('New Record!') 
                    stop_early = 0
                    saver = tf.train.Saver() 
                    saver.save(sess, checkpoint)

                else:
                    print("No Improvement.")
                    stop_early += 1
                    if stop_early == stop:
                        break
                update_loss = 0
            
                    
        # Reduce learning rate, but not below its minimum value
        learning_rate *= learning_rate_decay
        if learning_rate < min_learning_rate:
            learning_rate = min_learning_rate
        
        if stop_early == stop:
            print("Stopping Training.")
            break
# Out:
# Epoch   1/100 Batch   20/468 - Loss:  4.662, Seconds: 67.04
# Epoch   1/100 Batch   40/468 - Loss:  2.869, Seconds: 65.10
# Epoch   1/100 Batch   60/468 - Loss:  2.841, Seconds: 55.84
# Epoch   1/100 Batch   80/468 - Loss:  2.721, Seconds: 70.62
# Epoch   1/100 Batch  100/468 - Loss:  2.785, Seconds: 60.29
# Epoch   1/100 Batch  120/468 - Loss:  2.679, Seconds: 60.47
# Epoch   1/100 Batch  140/468 - Loss:  2.560, Seconds: 64.61
# Average loss for this update: 2.978
# New Record!
# Epoch   1/100 Batch  160/468 - Loss:  2.558, Seconds: 68.57
# Epoch   1/100 Batch  180/468 - Loss:  2.500, Seconds: 62.68
# Epoch   1/100 Batch  200/468 - Loss:  2.588, Seconds: 53.37
# Epoch   1/100 Batch  220/468 - Loss:  2.570, Seconds: 60.53
# Epoch   1/100 Batch  240/468 - Loss:  2.510, Seconds: 44.45
# Epoch   1/100 Batch  260/468 - Loss:  2.345, Seconds: 58.32
# Epoch   1/100 Batch  280/468 - Loss:  2.205, Seconds: 66.59
# Epoch   1/100 Batch  300/468 - Loss:  2.298, Seconds: 58.46
# Average loss for this update: 2.423
# New Record!
# Epoch   1/100 Batch  320/468 - Loss:  2.375, Seconds: 58.19
# Epoch   1/100 Batch  340/468 - Loss:  2.571, Seconds: 49.32
# Epoch   1/100 Batch  360/468 - Loss:  2.336, Seconds: 66.83
# Epoch   1/100 Batch  380/468 - Loss:  2.343, Seconds: 68.24
# Epoch   1/100 Batch  400/468 - Loss:  2.141, Seconds: 68.29
# Epoch   1/100 Batch  420/468 - Loss:  2.101, Seconds: 54.27
# Epoch   1/100 Batch  440/468 - Loss:  2.106, Seconds: 58.29
# Epoch   1/100 Batch  460/468 - Loss:  2.348, Seconds: 59.61
# Average loss for this update: 2.289
# New Record!
# Epoch   2/100 Batch   20/468 - Loss:  2.328, Seconds: 61.57
# Epoch   2/100 Batch   40/468 - Loss:  2.142, Seconds: 61.44
# Epoch   2/100 Batch   60/468 - Loss:  2.160, Seconds: 54.02
# Epoch   2/100 Batch   80/468 - Loss:  2.071, Seconds: 66.66
# Epoch   2/100 Batch  100/468 - Loss:  2.142, Seconds: 58.21
# Epoch   2/100 Batch  120/468 - Loss:  2.018, Seconds: 57.87
# Epoch   2/100 Batch  140/468 - Loss:  1.947, Seconds: 57.58
# Average loss for this update: 2.105
# New Record!
# Epoch   2/100 Batch  160/468 - Loss:  1.950, Seconds: 66.15
# Epoch   2/100 Batch  180/468 - Loss:  1.963, Seconds: 62.60
# Epoch   2/100 Batch  200/468 - Loss:  2.043, Seconds: 54.20
# Epoch   2/100 Batch  220/468 - Loss:  2.038, Seconds: 58.21
# Epoch   2/100 Batch  240/468 - Loss:  1.965, Seconds: 45.34
# Epoch   2/100 Batch  260/468 - Loss:  1.816, Seconds: 59.18
# Epoch   2/100 Batch  280/468 - Loss:  1.691, Seconds: 69.35
# Epoch   2/100 Batch  300/468 - Loss:  1.803, Seconds: 58.28
# Average loss for this update: 1.894
# New Record!
# Epoch   2/100 Batch  320/468 - Loss:  1.875, Seconds: 58.10
# Epoch   2/100 Batch  340/468 - Loss:  2.104, Seconds: 49.55
# Epoch   2/100 Batch  360/468 - Loss:  1.902, Seconds: 69.14
# Epoch   2/100 Batch  380/468 - Loss:  1.882, Seconds: 67.06
# Epoch   2/100 Batch  400/468 - Loss:  1.704, Seconds: 67.07
# Epoch   2/100 Batch  420/468 - Loss:  1.659, Seconds: 54.52
# Epoch   2/100 Batch  440/468 - Loss:  1.690, Seconds: 59.35
# Epoch   2/100 Batch  460/468 - Loss:  1.959, Seconds: 59.19
# Average loss for this update: 1.853
# New Record!
# Epoch   3/100 Batch   20/468 - Loss:  2.065, Seconds: 62.19
# Epoch   3/100 Batch   40/468 - Loss:  1.851, Seconds: 62.08
# Epoch   3/100 Batch   60/468 - Loss:  1.841, Seconds: 53.97
# Epoch   3/100 Batch   80/468 - Loss:  1.752, Seconds: 66.13
# Epoch   3/100 Batch  100/468 - Loss:  1.829, Seconds: 58.70
# Epoch   3/100 Batch  120/468 - Loss:  1.671, Seconds: 58.62
# Epoch   3/100 Batch  140/468 - Loss:  1.616, Seconds: 59.44
# Average loss for this update: 1.79
# New Record!
# Epoch   3/100 Batch  160/468 - Loss:  1.621, Seconds: 120.69
# Epoch   3/100 Batch  180/468 - Loss:  1.685, Seconds: 64.69
# Epoch   3/100 Batch  200/468 - Loss:  1.740, Seconds: 53.84
# Epoch   3/100 Batch  220/468 - Loss:  1.730, Seconds: 58.01
# Epoch   3/100 Batch  240/468 - Loss:  1.659, Seconds: 51.70
# Epoch   3/100 Batch  260/468 - Loss:  1.521, Seconds: 59.15
# Epoch   3/100 Batch  280/468 - Loss:  1.404, Seconds: 102.38
# Epoch   3/100 Batch  300/468 - Loss:  1.521, Seconds: 77.89
# Average loss for this update: 1.599
# New Record!
# Epoch   3/100 Batch  320/468 - Loss:  1.580, Seconds: 77.77
# Epoch   3/100 Batch  340/468 - Loss:  1.809, Seconds: 70.23
# Epoch   3/100 Batch  360/468 - Loss:  1.628, Seconds: 82.38
# Epoch   3/100 Batch  380/468 - Loss:  1.598, Seconds: 81.25
# Epoch   3/100 Batch  400/468 - Loss:  1.450, Seconds: 94.61
# Epoch   3/100 Batch  420/468 - Loss:  1.405, Seconds: 66.88
# Epoch   3/100 Batch  440/468 - Loss:  1.432, Seconds: 71.84
# Epoch   3/100 Batch  460/468 - Loss:  1.681, Seconds: 71.68
# Average loss for this update: 1.582
# New Record!
# Epoch   4/100 Batch   20/468 - Loss:  1.858, Seconds: 86.65
# Epoch   4/100 Batch   40/468 - Loss:  1.658, Seconds: 94.78
# Epoch   4/100 Batch   60/468 - Loss:  1.630, Seconds: 77.63
# Epoch   4/100 Batch   80/468 - Loss:  1.538, Seconds: 99.77
# Epoch   4/100 Batch  100/468 - Loss:  1.604, Seconds: 74.19
# Epoch   4/100 Batch  120/468 - Loss:  1.443, Seconds: 82.09
# Epoch   4/100 Batch  140/468 - Loss:  1.400, Seconds: 90.97
# Average loss for this update: 1.579
# New Record!
# Epoch   4/100 Batch  160/468 - Loss:  1.428, Seconds: 100.32
# Epoch   4/100 Batch  180/468 - Loss:  1.490, Seconds: 97.26
# Epoch   4/100 Batch  200/468 - Loss:  1.536, Seconds: 72.56
# Epoch   4/100 Batch  220/468 - Loss:  1.529, Seconds: 83.07
# Epoch   4/100 Batch  240/468 - Loss:  1.446, Seconds: 45.13
# Epoch   4/100 Batch  260/468 - Loss:  1.346, Seconds: 57.99
# Epoch   4/100 Batch  280/468 - Loss:  1.228, Seconds: 66.99
# Epoch   4/100 Batch  300/468 - Loss:  1.350, Seconds: 58.20
# Average loss for this update: 1.408
# New Record!
# Epoch   4/100 Batch  320/468 - Loss:  1.396, Seconds: 59.09
# Epoch   4/100 Batch  340/468 - Loss:  1.595, Seconds: 50.08
# Epoch   4/100 Batch  360/468 - Loss:  1.453, Seconds: 68.97
# Epoch   4/100 Batch  380/468 - Loss:  1.412, Seconds: 67.71
# Epoch   4/100 Batch  400/468 - Loss:  1.298, Seconds: 67.48
# Epoch   4/100 Batch  420/468 - Loss:  1.245, Seconds: 54.48
# Epoch   4/100 Batch  440/468 - Loss:  1.269, Seconds: 58.24
# Epoch   4/100 Batch  460/468 - Loss:  1.497, Seconds: 59.01
# Average loss for this update: 1.406
# New Record!
# Epoch   5/100 Batch   20/468 - Loss:  1.700, Seconds: 64.00
# Epoch   5/100 Batch   40/468 - Loss:  1.495, Seconds: 62.58
# Epoch   5/100 Batch   60/468 - Loss:  1.462, Seconds: 53.49
# Epoch   5/100 Batch   80/468 - Loss:  1.397, Seconds: 66.72
# Epoch   5/100 Batch  100/468 - Loss:  1.445, Seconds: 59.18
# Epoch   5/100 Batch  120/468 - Loss:  1.288, Seconds: 58.32
# Epoch   5/100 Batch  140/468 - Loss:  1.258, Seconds: 58.24
# Average loss for this update: 1.424
# No Improvement.
# Epoch   5/100 Batch  160/468 - Loss:  1.295, Seconds: 66.61
# Epoch   5/100 Batch  180/468 - Loss:  1.348, Seconds: 63.43
# Epoch   5/100 Batch  200/468 - Loss:  1.389, Seconds: 53.51
# Epoch   5/100 Batch  220/468 - Loss:  1.381, Seconds: 58.49
# Epoch   5/100 Batch  240/468 - Loss:  1.302, Seconds: 45.38
# Epoch   5/100 Batch  260/468 - Loss:  1.212, Seconds: 59.01
# Epoch   5/100 Batch  280/468 - Loss:  1.092, Seconds: 67.78
# Epoch   5/100 Batch  300/468 - Loss:  1.222, Seconds: 59.30
# Average loss for this update: 1.27
# New Record!
# Epoch   5/100 Batch  320/468 - Loss:  1.255, Seconds: 58.05
# Epoch   5/100 Batch  340/468 - Loss:  1.441, Seconds: 50.67
# Epoch   5/100 Batch  360/468 - Loss:  1.324, Seconds: 85.97
# Epoch   5/100 Batch  380/468 - Loss:  1.264, Seconds: 94.50
# Epoch   5/100 Batch  400/468 - Loss:  1.169, Seconds: 95.84
# Epoch   5/100 Batch  420/468 - Loss:  1.117, Seconds: 77.72
# Epoch   5/100 Batch  440/468 - Loss:  1.148, Seconds: 76.52
# Epoch   5/100 Batch  460/468 - Loss:  1.363, Seconds: 81.49
# Average loss for this update: 1.271
# No Improvement.
# Epoch   6/100 Batch   20/468 - Loss:  1.565, Seconds: 90.80
# Epoch   6/100 Batch   40/468 - Loss:  1.383, Seconds: 85.98
# Epoch   6/100 Batch   60/468 - Loss:  1.328, Seconds: 71.63
# Epoch   6/100 Batch   80/468 - Loss:  1.277, Seconds: 82.81
# Epoch   6/100 Batch  100/468 - Loss:  1.312, Seconds: 81.73
# Epoch   6/100 Batch  120/468 - Loss:  1.186, Seconds: 61.17
# Epoch   6/100 Batch  140/468 - Loss:  1.134, Seconds: 58.79
# Average loss for this update: 1.302
# No Improvement.
# Epoch   6/100 Batch  160/468 - Loss:  1.174, Seconds: 68.16
# Epoch   6/100 Batch  180/468 - Loss:  1.233, Seconds: 77.02
# Epoch   6/100 Batch  200/468 - Loss:  1.259, Seconds: 57.52
# Epoch   6/100 Batch  220/468 - Loss:  1.255, Seconds: 70.99
# Epoch   6/100 Batch  240/468 - Loss:  1.178, Seconds: 59.74
# Epoch   6/100 Batch  260/468 - Loss:  1.106, Seconds: 68.59
# Epoch   6/100 Batch  280/468 - Loss:  0.985, Seconds: 71.71
# Epoch   6/100 Batch  300/468 - Loss:  1.122, Seconds: 59.45
# Average loss for this update: 1.158
# New Record!
# Epoch   6/100 Batch  320/468 - Loss:  1.200, Seconds: 58.79
# Epoch   6/100 Batch  340/468 - Loss:  1.376, Seconds: 49.48
# Epoch   6/100 Batch  360/468 - Loss:  1.258, Seconds: 66.36
# Epoch   6/100 Batch  380/468 - Loss:  1.198, Seconds: 67.66
# Epoch   6/100 Batch  400/468 - Loss:  1.114, Seconds: 72.88
# Epoch   6/100 Batch  420/468 - Loss:  1.038, Seconds: 53.84
# Epoch   6/100 Batch  440/468 - Loss:  1.090, Seconds: 59.10
# Epoch   6/100 Batch  460/468 - Loss:  1.273, Seconds: 58.25
# Average loss for this update: 1.203
# No Improvement.
# Epoch   7/100 Batch   20/468 - Loss:  1.455, Seconds: 62.79
# Epoch   7/100 Batch   40/468 - Loss:  1.288, Seconds: 62.88
# Epoch   7/100 Batch   60/468 - Loss:  1.237, Seconds: 53.05
# Epoch   7/100 Batch   80/468 - Loss:  1.177, Seconds: 66.14
# Epoch   7/100 Batch  100/468 - Loss:  1.205, Seconds: 58.12
# Epoch   7/100 Batch  120/468 - Loss:  1.093, Seconds: 58.21
# Epoch   7/100 Batch  140/468 - Loss:  1.055, Seconds: 58.95
# Average loss for this update: 1.207
# No Improvement.
# Epoch   7/100 Batch  160/468 - Loss:  1.095, Seconds: 66.59
# Epoch   7/100 Batch  180/468 - Loss:  1.133, Seconds: 61.98
# Epoch   7/100 Batch  200/468 - Loss:  1.170, Seconds: 53.34
# Epoch   7/100 Batch  220/468 - Loss:  1.143, Seconds: 59.87
# Epoch   7/100 Batch  240/468 - Loss:  1.094, Seconds: 45.09
# Epoch   7/100 Batch  260/468 - Loss:  1.022, Seconds: 58.55
# Epoch   7/100 Batch  280/468 - Loss:  0.918, Seconds: 67.60
# Epoch   7/100 Batch  300/468 - Loss:  1.039, Seconds: 58.94
# Average loss for this update: 1.068
# New Record!
# Epoch   7/100 Batch  320/468 - Loss:  1.072, Seconds: 58.33
# Epoch   7/100 Batch  340/468 - Loss:  1.217, Seconds: 58.70
# Epoch   7/100 Batch  360/468 - Loss:  1.131, Seconds: 68.69
# Epoch   7/100 Batch  380/468 - Loss:  1.070, Seconds: 67.53
# Epoch   7/100 Batch  400/468 - Loss:  1.010, Seconds: 67.86
# Epoch   7/100 Batch  420/468 - Loss:  0.948, Seconds: 54.31
# Epoch   7/100 Batch  440/468 - Loss:  0.991, Seconds: 58.87
# Epoch   7/100 Batch  460/468 - Loss:  1.162, Seconds: 58.36
# Average loss for this update: 1.086
# No Improvement.
# Epoch   8/100 Batch   20/468 - Loss:  1.348, Seconds: 62.89
# Epoch   8/100 Batch   40/468 - Loss:  1.191, Seconds: 62.73
# Epoch   8/100 Batch   60/468 - Loss:  1.132, Seconds: 54.27
# Epoch   8/100 Batch   80/468 - Loss:  1.068, Seconds: 67.59
# Epoch   8/100 Batch  100/468 - Loss:  1.098, Seconds: 58.40
# Epoch   8/100 Batch  120/468 - Loss:  1.000, Seconds: 58.10
# Epoch   8/100 Batch  140/468 - Loss:  0.974, Seconds: 58.90
# Average loss for this update: 1.107
# No Improvement.
# Epoch   8/100 Batch  160/468 - Loss:  1.004, Seconds: 71.90
# Epoch   8/100 Batch  180/468 - Loss:  1.046, Seconds: 63.89
# Epoch   8/100 Batch  200/468 - Loss:  1.072, Seconds: 53.73
# Epoch   8/100 Batch  220/468 - Loss:  1.051, Seconds: 58.16
# Epoch   8/100 Batch  240/468 - Loss:  0.997, Seconds: 45.16
# Epoch   8/100 Batch  260/468 - Loss:  0.937, Seconds: 58.03
# Epoch   8/100 Batch  280/468 - Loss:  0.850, Seconds: 66.61
# Epoch   8/100 Batch  300/468 - Loss:  0.972, Seconds: 57.77
# Average loss for this update: 0.985
# New Record!
# Epoch   8/100 Batch  320/468 - Loss:  0.996, Seconds: 58.45
# Epoch   8/100 Batch  340/468 - Loss:  1.136, Seconds: 52.33
# Epoch   8/100 Batch  360/468 - Loss:  1.055, Seconds: 68.19
# Epoch   8/100 Batch  380/468 - Loss:  0.991, Seconds: 68.61
# Epoch   8/100 Batch  400/468 - Loss:  0.970, Seconds: 68.00
# Epoch   8/100 Batch  420/468 - Loss:  0.897, Seconds: 53.99
# Epoch   8/100 Batch  440/468 - Loss:  0.928, Seconds: 58.99
# Epoch   8/100 Batch  460/468 - Loss:  1.096, Seconds: 58.14
# Average loss for this update: 1.019
# No Improvement.
# Epoch   9/100 Batch   20/468 - Loss:  1.267, Seconds: 62.55
# Epoch   9/100 Batch   40/468 - Loss:  1.116, Seconds: 62.33
# Epoch   9/100 Batch   60/468 - Loss:  1.058, Seconds: 53.58
# Epoch   9/100 Batch   80/468 - Loss:  1.005, Seconds: 67.43
# Epoch   9/100 Batch  100/468 - Loss:  1.030, Seconds: 57.95
# Epoch   9/100 Batch  120/468 - Loss:  0.925, Seconds: 57.51
# Epoch   9/100 Batch  140/468 - Loss:  0.917, Seconds: 58.47
# Average loss for this update: 1.038
# No Improvement.
# Epoch   9/100 Batch  160/468 - Loss:  0.947, Seconds: 66.35
# Epoch   9/100 Batch  180/468 - Loss:  0.986, Seconds: 62.53
# Epoch   9/100 Batch  200/468 - Loss:  1.012, Seconds: 54.06
# Epoch   9/100 Batch  220/468 - Loss:  0.994, Seconds: 58.85
# Epoch   9/100 Batch  240/468 - Loss:  0.932, Seconds: 45.35
# Epoch   9/100 Batch  260/468 - Loss:  0.889, Seconds: 58.67
# Epoch   9/100 Batch  280/468 - Loss:  0.807, Seconds: 67.73
# Epoch   9/100 Batch  300/468 - Loss:  0.935, Seconds: 57.74
# Average loss for this update: 0.931
# New Record!
# Epoch   9/100 Batch  320/468 - Loss:  0.931, Seconds: 62.05
# Epoch   9/100 Batch  340/468 - Loss:  1.056, Seconds: 70.31
# Epoch   9/100 Batch  360/468 - Loss:  0.977, Seconds: 85.47
# Epoch   9/100 Batch  380/468 - Loss:  0.938, Seconds: 91.22
# Epoch   9/100 Batch  400/468 - Loss:  0.889, Seconds: 94.31
# Epoch   9/100 Batch  420/468 - Loss:  0.829, Seconds: 65.19
# Epoch   9/100 Batch  440/468 - Loss:  0.862, Seconds: 60.27
# Epoch   9/100 Batch  460/468 - Loss:  1.016, Seconds: 59.19
# Average loss for this update: 0.948
# No Improvement.
# Epoch  10/100 Batch   20/468 - Loss:  1.188, Seconds: 70.80
# Epoch  10/100 Batch   40/468 - Loss:  1.054, Seconds: 69.26
# Epoch  10/100 Batch   60/468 - Loss:  0.990, Seconds: 61.07
# Epoch  10/100 Batch   80/468 - Loss:  0.955, Seconds: 76.16
# Epoch  10/100 Batch  100/468 - Loss:  0.958, Seconds: 61.69
# Epoch  10/100 Batch  120/468 - Loss:  0.880, Seconds: 82.93
# Epoch  10/100 Batch  140/468 - Loss:  0.852, Seconds: 83.90
# Average loss for this update: 0.976
# No Improvement.
# Epoch  10/100 Batch  160/468 - Loss:  0.897, Seconds: 97.03
# Epoch  10/100 Batch  180/468 - Loss:  0.935, Seconds: 91.86
# Epoch  10/100 Batch  200/468 - Loss:  0.956, Seconds: 79.33
# Epoch  10/100 Batch  220/468 - Loss:  0.922, Seconds: 84.67
# Epoch  10/100 Batch  240/468 - Loss:  0.883, Seconds: 62.72
# Epoch  10/100 Batch  260/468 - Loss:  0.836, Seconds: 81.57
# Epoch  10/100 Batch  280/468 - Loss:  0.756, Seconds: 97.34
# Epoch  10/100 Batch  300/468 - Loss:  0.883, Seconds: 82.35
# Average loss for this update: 0.876
# New Record!
# Epoch  10/100 Batch  320/468 - Loss:  0.879, Seconds: 62.39
# Epoch  10/100 Batch  340/468 - Loss:  0.990, Seconds: 50.47
# Epoch  10/100 Batch  360/468 - Loss:  0.937, Seconds: 68.10
# Epoch  10/100 Batch  380/468 - Loss:  0.873, Seconds: 69.79
# Epoch  10/100 Batch  400/468 - Loss:  0.839, Seconds: 67.91
# Epoch  10/100 Batch  420/468 - Loss:  0.786, Seconds: 55.34
# Epoch  10/100 Batch  440/468 - Loss:  0.824, Seconds: 58.36
# Epoch  10/100 Batch  460/468 - Loss:  0.969, Seconds: 58.99
# Average loss for this update: 0.897
# No Improvement.
# Epoch  11/100 Batch   20/468 - Loss:  1.121, Seconds: 62.40
# Epoch  11/100 Batch   40/468 - Loss:  1.001, Seconds: 61.77
# Epoch  11/100 Batch   60/468 - Loss:  0.940, Seconds: 53.29
# Epoch  11/100 Batch   80/468 - Loss:  0.901, Seconds: 66.72
# Epoch  11/100 Batch  100/468 - Loss:  0.913, Seconds: 58.07
# Epoch  11/100 Batch  120/468 - Loss:  0.820, Seconds: 58.27
# Epoch  11/100 Batch  140/468 - Loss:  0.793, Seconds: 57.74
# Average loss for this update: 0.92
# No Improvement.
# Epoch  11/100 Batch  160/468 - Loss:  0.833, Seconds: 67.60
# Epoch  11/100 Batch  180/468 - Loss:  0.869, Seconds: 61.73
# Epoch  11/100 Batch  200/468 - Loss:  0.895, Seconds: 54.96
# Epoch  11/100 Batch  220/468 - Loss:  0.864, Seconds: 58.69
# Epoch  11/100 Batch  240/468 - Loss:  0.833, Seconds: 45.25
# Epoch  11/100 Batch  260/468 - Loss:  0.786, Seconds: 58.30
# Epoch  11/100 Batch  280/468 - Loss:  0.723, Seconds: 66.82
# Epoch  11/100 Batch  300/468 - Loss:  0.826, Seconds: 58.17
# Average loss for this update: 0.822
# New Record!
# Epoch  11/100 Batch  320/468 - Loss:  0.821, Seconds: 59.58
# Epoch  11/100 Batch  340/468 - Loss:  0.942, Seconds: 49.20
# Epoch  11/100 Batch  360/468 - Loss:  0.879, Seconds: 67.61
# Epoch  11/100 Batch  380/468 - Loss:  0.836, Seconds: 67.66
# Epoch  11/100 Batch  400/468 - Loss:  0.804, Seconds: 66.46
# Epoch  11/100 Batch  420/468 - Loss:  0.755, Seconds: 53.86
# Epoch  11/100 Batch  440/468 - Loss:  0.774, Seconds: 57.80
# Epoch  11/100 Batch  460/468 - Loss:  0.910, Seconds: 59.18
# Average loss for this update: 0.851
# No Improvement.
# Epoch  12/100 Batch   20/468 - Loss:  1.067, Seconds: 63.50
# Epoch  12/100 Batch   40/468 - Loss:  0.943, Seconds: 62.57
# Epoch  12/100 Batch   60/468 - Loss:  0.887, Seconds: 53.40
# Epoch  12/100 Batch   80/468 - Loss:  0.853, Seconds: 66.72
# Epoch  12/100 Batch  100/468 - Loss:  0.860, Seconds: 57.90
# Epoch  12/100 Batch  120/468 - Loss:  0.776, Seconds: 58.20
# Epoch  12/100 Batch  140/468 - Loss:  0.767, Seconds: 59.37
# Average loss for this update: 0.875
# No Improvement.
# Epoch  12/100 Batch  160/468 - Loss:  0.810, Seconds: 66.42
# Epoch  12/100 Batch  180/468 - Loss:  0.828, Seconds: 62.70
# Epoch  12/100 Batch  200/468 - Loss:  0.839, Seconds: 53.44
# Epoch  12/100 Batch  220/468 - Loss:  0.820, Seconds: 58.20
# Epoch  12/100 Batch  240/468 - Loss:  0.778, Seconds: 46.43
# Epoch  12/100 Batch  260/468 - Loss:  0.741, Seconds: 58.76
# Epoch  12/100 Batch  280/468 - Loss:  0.673, Seconds: 68.18
# Epoch  12/100 Batch  300/468 - Loss:  0.772, Seconds: 58.37
# Average loss for this update: 0.773
# New Record!
# Epoch  12/100 Batch  320/468 - Loss:  0.768, Seconds: 60.44
# Epoch  12/100 Batch  340/468 - Loss:  0.881, Seconds: 49.55
# Epoch  12/100 Batch  360/468 - Loss:  0.832, Seconds: 67.79
# Epoch  12/100 Batch  380/468 - Loss:  0.787, Seconds: 67.30
# Epoch  12/100 Batch  400/468 - Loss:  0.763, Seconds: 67.08
# Epoch  12/100 Batch  420/468 - Loss:  0.696, Seconds: 53.55
# Epoch  12/100 Batch  440/468 - Loss:  0.736, Seconds: 58.51
# Epoch  12/100 Batch  460/468 - Loss:  0.859, Seconds: 59.54
# Average loss for this update: 0.8
# No Improvement.
# Epoch  13/100 Batch   20/468 - Loss:  1.004, Seconds: 61.91
# Epoch  13/100 Batch   40/468 - Loss:  0.893, Seconds: 62.64
# Epoch  13/100 Batch   60/468 - Loss:  0.837, Seconds: 52.85
# Epoch  13/100 Batch   80/468 - Loss:  0.809, Seconds: 66.01
# Epoch  13/100 Batch  100/468 - Loss:  0.819, Seconds: 57.97
# Epoch  13/100 Batch  120/468 - Loss:  0.737, Seconds: 59.33
# Epoch  13/100 Batch  140/468 - Loss:  0.726, Seconds: 57.60
# Average loss for this update: 0.828
# No Improvement.
# Epoch  13/100 Batch  160/468 - Loss:  0.764, Seconds: 66.30
# Epoch  13/100 Batch  180/468 - Loss:  0.793, Seconds: 63.41
# Epoch  13/100 Batch  200/468 - Loss:  0.818, Seconds: 54.14
# Epoch  13/100 Batch  220/468 - Loss:  0.771, Seconds: 59.07
# Epoch  13/100 Batch  240/468 - Loss:  0.743, Seconds: 45.89
# Epoch  13/100 Batch  260/468 - Loss:  0.714, Seconds: 57.68
# Epoch  13/100 Batch  280/468 - Loss:  0.653, Seconds: 67.86
# Epoch  13/100 Batch  300/468 - Loss:  0.754, Seconds: 57.68
# Average loss for this update: 0.744
# New Record!
# Epoch  13/100 Batch  320/468 - Loss:  0.731, Seconds: 58.49
# Epoch  13/100 Batch  340/468 - Loss:  0.837, Seconds: 50.46
# Epoch  13/100 Batch  360/468 - Loss:  0.789, Seconds: 68.60
# Epoch  13/100 Batch  380/468 - Loss:  0.746, Seconds: 67.08
# Epoch  13/100 Batch  400/468 - Loss:  0.726, Seconds: 67.65
# Epoch  13/100 Batch  420/468 - Loss:  0.675, Seconds: 53.45
# Epoch  13/100 Batch  440/468 - Loss:  0.717, Seconds: 58.47
# Epoch  13/100 Batch  460/468 - Loss:  0.826, Seconds: 60.28
# Average loss for this update: 0.765
# No Improvement.
# Epoch  14/100 Batch   20/468 - Loss:  0.962, Seconds: 62.19
# Epoch  14/100 Batch   40/468 - Loss:  0.851, Seconds: 62.81
# Epoch  14/100 Batch   60/468 - Loss:  0.803, Seconds: 53.30
# Epoch  14/100 Batch   80/468 - Loss:  0.775, Seconds: 66.95
# Epoch  14/100 Batch  100/468 - Loss:  0.781, Seconds: 59.20
# Epoch  14/100 Batch  120/468 - Loss:  0.704, Seconds: 58.74
# Epoch  14/100 Batch  140/468 - Loss:  0.707, Seconds: 57.57
# Average loss for this update: 0.793
# No Improvement.
# Epoch  14/100 Batch  160/468 - Loss:  0.736, Seconds: 66.72
# Epoch  14/100 Batch  180/468 - Loss:  0.758, Seconds: 62.94
# Epoch  14/100 Batch  200/468 - Loss:  0.776, Seconds: 54.42
# Epoch  14/100 Batch  220/468 - Loss:  0.753, Seconds: 57.46
# Epoch  14/100 Batch  240/468 - Loss:  0.716, Seconds: 44.93
# Epoch  14/100 Batch  260/468 - Loss:  0.679, Seconds: 59.13
# Epoch  14/100 Batch  280/468 - Loss:  0.617, Seconds: 66.58
# Epoch  14/100 Batch  300/468 - Loss:  0.731, Seconds: 58.70
# Average loss for this update: 0.714
# New Record!
# Epoch  14/100 Batch  320/468 - Loss:  0.708, Seconds: 58.49
# Epoch  14/100 Batch  340/468 - Loss:  0.805, Seconds: 50.03
# Epoch  14/100 Batch  360/468 - Loss:  0.751, Seconds: 66.51
# Epoch  14/100 Batch  380/468 - Loss:  0.716, Seconds: 67.71
# Epoch  14/100 Batch  400/468 - Loss:  0.699, Seconds: 67.96
# Epoch  14/100 Batch  420/468 - Loss:  0.664, Seconds: 53.95
# Epoch  14/100 Batch  440/468 - Loss:  0.673, Seconds: 58.00
# Epoch  14/100 Batch  460/468 - Loss:  0.793, Seconds: 58.52
# Average loss for this update: 0.736
# No Improvement.
# Epoch  15/100 Batch   20/468 - Loss:  0.914, Seconds: 62.52
# Epoch  15/100 Batch   40/468 - Loss:  0.820, Seconds: 62.33
# Epoch  15/100 Batch   60/468 - Loss:  0.765, Seconds: 54.57
# Epoch  15/100 Batch   80/468 - Loss:  0.739, Seconds: 68.82
# Epoch  15/100 Batch  100/468 - Loss:  0.752, Seconds: 58.57
# Epoch  15/100 Batch  120/468 - Loss:  0.686, Seconds: 57.48
# Epoch  15/100 Batch  140/468 - Loss:  0.655, Seconds: 58.99
# Average loss for this update: 0.757
# No Improvement.
# Epoch  15/100 Batch  160/468 - Loss:  0.695, Seconds: 67.01
# Epoch  15/100 Batch  180/468 - Loss:  0.716, Seconds: 62.67
# Epoch  15/100 Batch  200/468 - Loss:  0.736, Seconds: 53.36
# Epoch  15/100 Batch  220/468 - Loss:  0.706, Seconds: 58.21
# Epoch  15/100 Batch  240/468 - Loss:  0.688, Seconds: 45.11
# Epoch  15/100 Batch  260/468 - Loss:  0.642, Seconds: 57.32
# Epoch  15/100 Batch  280/468 - Loss:  0.600, Seconds: 68.33
# Epoch  15/100 Batch  300/468 - Loss:  0.696, Seconds: 59.13
# Average loss for this update: 0.678
# New Record!
# Epoch  15/100 Batch  320/468 - Loss:  0.663, Seconds: 58.65
# Epoch  15/100 Batch  340/468 - Loss:  0.778, Seconds: 49.95
# Epoch  15/100 Batch  360/468 - Loss:  0.707, Seconds: 66.92
# Epoch  15/100 Batch  380/468 - Loss:  0.672, Seconds: 67.56
# Epoch  15/100 Batch  400/468 - Loss:  0.673, Seconds: 68.07
# Epoch  15/100 Batch  420/468 - Loss:  0.627, Seconds: 54.75
# Epoch  15/100 Batch  440/468 - Loss:  0.658, Seconds: 57.60
# Epoch  15/100 Batch  460/468 - Loss:  0.758, Seconds: 59.11
# Average loss for this update: 0.701
# No Improvement.
# Epoch  16/100 Batch   20/468 - Loss:  0.876, Seconds: 61.08
# Epoch  16/100 Batch   40/468 - Loss:  0.782, Seconds: 62.29
# Epoch  16/100 Batch   60/468 - Loss:  0.737, Seconds: 56.40
# Epoch  16/100 Batch   80/468 - Loss:  0.700, Seconds: 67.53
# Epoch  16/100 Batch  100/468 - Loss:  0.706, Seconds: 57.59
# Epoch  16/100 Batch  120/468 - Loss:  0.642, Seconds: 58.15
# Epoch  16/100 Batch  140/468 - Loss:  0.624, Seconds: 58.03
# Average loss for this update: 0.719
# No Improvement.
# Epoch  16/100 Batch  160/468 - Loss:  0.661, Seconds: 67.71
# Epoch  16/100 Batch  180/468 - Loss:  0.696, Seconds: 62.39
# Epoch  16/100 Batch  200/468 - Loss:  0.713, Seconds: 54.36
# Epoch  16/100 Batch  220/468 - Loss:  0.689, Seconds: 57.93
# Epoch  16/100 Batch  240/468 - Loss:  0.663, Seconds: 45.32
# Epoch  16/100 Batch  260/468 - Loss:  0.625, Seconds: 57.84
# Epoch  16/100 Batch  280/468 - Loss:  0.558, Seconds: 67.54
# Epoch  16/100 Batch  300/468 - Loss:  0.665, Seconds: 58.18
# Average loss for this update: 0.654
# New Record!
# Epoch  16/100 Batch  320/468 - Loss:  0.646, Seconds: 58.18
# Epoch  16/100 Batch  340/468 - Loss:  0.737, Seconds: 49.13
# Epoch  16/100 Batch  360/468 - Loss:  0.680, Seconds: 67.57
# Epoch  16/100 Batch  380/468 - Loss:  0.651, Seconds: 67.13
# Epoch  16/100 Batch  400/468 - Loss:  0.651, Seconds: 67.94
# Epoch  16/100 Batch  420/468 - Loss:  0.598, Seconds: 54.52
# Epoch  16/100 Batch  440/468 - Loss:  0.627, Seconds: 58.72
# Epoch  16/100 Batch  460/468 - Loss:  0.715, Seconds: 58.11
# Average loss for this update: 0.672
# No Improvement.
# Epoch  17/100 Batch   20/468 - Loss:  0.838, Seconds: 61.22
# Epoch  17/100 Batch   40/468 - Loss:  0.764, Seconds: 64.55
# Epoch  17/100 Batch   60/468 - Loss:  0.700, Seconds: 53.50
# Epoch  17/100 Batch   80/468 - Loss:  0.669, Seconds: 67.86
# Epoch  17/100 Batch  100/468 - Loss:  0.681, Seconds: 58.23
# Epoch  17/100 Batch  120/468 - Loss:  0.615, Seconds: 57.58
# Epoch  17/100 Batch  140/468 - Loss:  0.612, Seconds: 59.12
# Average loss for this update: 0.694
# No Improvement.
# Epoch  17/100 Batch  160/468 - Loss:  0.646, Seconds: 67.22
# Epoch  17/100 Batch  180/468 - Loss:  0.667, Seconds: 62.65
# Epoch  17/100 Batch  200/468 - Loss:  0.685, Seconds: 54.01
# Epoch  17/100 Batch  220/468 - Loss:  0.662, Seconds: 58.16
# Epoch  17/100 Batch  240/468 - Loss:  0.634, Seconds: 44.82
# Epoch  17/100 Batch  260/468 - Loss:  0.596, Seconds: 57.63
# Epoch  17/100 Batch  280/468 - Loss:  0.547, Seconds: 67.39
# Epoch  17/100 Batch  300/468 - Loss:  0.634, Seconds: 58.99
# Average loss for this update: 0.627
# New Record!
# Epoch  17/100 Batch  320/468 - Loss:  0.604, Seconds: 59.37
# Epoch  17/100 Batch  340/468 - Loss:  0.699, Seconds: 49.90
# Epoch  17/100 Batch  360/468 - Loss:  0.664, Seconds: 67.07
# Epoch  17/100 Batch  380/468 - Loss:  0.630, Seconds: 68.32
# Epoch  17/100 Batch  400/468 - Loss:  0.625, Seconds: 67.81
# Epoch  17/100 Batch  420/468 - Loss:  0.586, Seconds: 54.67
# Epoch  17/100 Batch  440/468 - Loss:  0.609, Seconds: 58.12
# Epoch  17/100 Batch  460/468 - Loss:  0.687, Seconds: 58.37
# Average loss for this update: 0.648
# No Improvement.
# Epoch  18/100 Batch   20/468 - Loss:  0.818, Seconds: 63.04
# Epoch  18/100 Batch   40/468 - Loss:  0.722, Seconds: 62.37
# Epoch  18/100 Batch   60/468 - Loss:  0.676, Seconds: 54.01
# Epoch  18/100 Batch   80/468 - Loss:  0.660, Seconds: 66.12
# Epoch  18/100 Batch  100/468 - Loss:  0.669, Seconds: 57.85
# Epoch  18/100 Batch  120/468 - Loss:  0.608, Seconds: 57.01
# Epoch  18/100 Batch  140/468 - Loss:  0.591, Seconds: 58.33
# Average loss for this update: 0.674
# No Improvement.
# Epoch  18/100 Batch  160/468 - Loss:  0.624, Seconds: 65.90
# Epoch  18/100 Batch  180/468 - Loss:  0.644, Seconds: 62.97
# Epoch  18/100 Batch  200/468 - Loss:  0.655, Seconds: 54.93
# Epoch  18/100 Batch  220/468 - Loss:  0.628, Seconds: 57.82
# Epoch  18/100 Batch  240/468 - Loss:  0.609, Seconds: 44.87
# Epoch  18/100 Batch  260/468 - Loss:  0.587, Seconds: 58.64
# Epoch  18/100 Batch  280/468 - Loss:  0.542, Seconds: 67.14
# Epoch  18/100 Batch  300/468 - Loss:  0.616, Seconds: 57.67
# Average loss for this update: 0.608
# New Record!
# Epoch  18/100 Batch  320/468 - Loss:  0.592, Seconds: 58.50
# Epoch  18/100 Batch  340/468 - Loss:  0.688, Seconds: 49.63
# Epoch  18/100 Batch  360/468 - Loss:  0.633, Seconds: 67.43
# Epoch  18/100 Batch  380/468 - Loss:  0.600, Seconds: 67.30
# Epoch  18/100 Batch  400/468 - Loss:  0.608, Seconds: 68.58
# Epoch  18/100 Batch  420/468 - Loss:  0.558, Seconds: 54.12
# Epoch  18/100 Batch  440/468 - Loss:  0.580, Seconds: 58.45
# Epoch  18/100 Batch  460/468 - Loss:  0.676, Seconds: 58.58
# Average loss for this update: 0.626
# No Improvement.
# Epoch  19/100 Batch   20/468 - Loss:  0.783, Seconds: 62.17
# Epoch  19/100 Batch   40/468 - Loss:  0.689, Seconds: 62.69
# Epoch  19/100 Batch   60/468 - Loss:  0.663, Seconds: 54.31
# Epoch  19/100 Batch   80/468 - Loss:  0.618, Seconds: 67.48
# Epoch  19/100 Batch  100/468 - Loss:  0.635, Seconds: 58.10
# Epoch  19/100 Batch  120/468 - Loss:  0.582, Seconds: 58.23
# Epoch  19/100 Batch  140/468 - Loss:  0.580, Seconds: 58.78
# Average loss for this update: 0.648
# No Improvement.
# Epoch  19/100 Batch  160/468 - Loss:  0.612, Seconds: 67.51
# Epoch  19/100 Batch  180/468 - Loss:  0.621, Seconds: 62.67
# Epoch  19/100 Batch  200/468 - Loss:  0.630, Seconds: 54.98
# Epoch  19/100 Batch  220/468 - Loss:  0.611, Seconds: 58.56
# Epoch  19/100 Batch  240/468 - Loss:  0.598, Seconds: 45.19
# Epoch  19/100 Batch  260/468 - Loss:  0.557, Seconds: 57.74
# Epoch  19/100 Batch  280/468 - Loss:  0.507, Seconds: 67.28
# Epoch  19/100 Batch  300/468 - Loss:  0.607, Seconds: 58.16
# Average loss for this update: 0.586
# New Record!
# Epoch  19/100 Batch  320/468 - Loss:  0.580, Seconds: 59.14
# Epoch  19/100 Batch  340/468 - Loss:  0.648, Seconds: 49.64
# Epoch  19/100 Batch  360/468 - Loss:  0.616, Seconds: 66.95
# Epoch  19/100 Batch  380/468 - Loss:  0.583, Seconds: 68.41
# Epoch  19/100 Batch  400/468 - Loss:  0.591, Seconds: 67.61
# Epoch  19/100 Batch  420/468 - Loss:  0.552, Seconds: 53.67
# Epoch  19/100 Batch  440/468 - Loss:  0.570, Seconds: 57.28
# Epoch  19/100 Batch  460/468 - Loss:  0.644, Seconds: 59.53
# Average loss for this update: 0.607
# No Improvement.
# Epoch  20/100 Batch   20/468 - Loss:  0.748, Seconds: 63.86
# Epoch  20/100 Batch   40/468 - Loss:  0.664, Seconds: 63.17
# Epoch  20/100 Batch   60/468 - Loss:  0.651, Seconds: 53.36
# Epoch  20/100 Batch   80/468 - Loss:  0.607, Seconds: 67.06
# Epoch  20/100 Batch  100/468 - Loss:  0.605, Seconds: 57.90
# Epoch  20/100 Batch  120/468 - Loss:  0.568, Seconds: 57.53
# Epoch  20/100 Batch  140/468 - Loss:  0.556, Seconds: 59.09
# Average loss for this update: 0.626
# No Improvement.
# Epoch  20/100 Batch  160/468 - Loss:  0.593, Seconds: 67.05
# Epoch  20/100 Batch  180/468 - Loss:  0.605, Seconds: 62.69
# Epoch  20/100 Batch  200/468 - Loss:  0.614, Seconds: 54.75
# Epoch  20/100 Batch  220/468 - Loss:  0.593, Seconds: 57.83
# Epoch  20/100 Batch  240/468 - Loss:  0.581, Seconds: 45.22
# Epoch  20/100 Batch  260/468 - Loss:  0.537, Seconds: 58.06
# Epoch  20/100 Batch  280/468 - Loss:  0.489, Seconds: 67.61
# Epoch  20/100 Batch  300/468 - Loss:  0.590, Seconds: 57.39
# Average loss for this update: 0.569
# New Record!
# Epoch  20/100 Batch  320/468 - Loss:  0.564, Seconds: 58.52
# Epoch  20/100 Batch  340/468 - Loss:  0.633, Seconds: 49.95
# Epoch  20/100 Batch  360/468 - Loss:  0.601, Seconds: 67.52
# Epoch  20/100 Batch  380/468 - Loss:  0.575, Seconds: 67.69
# Epoch  20/100 Batch  400/468 - Loss:  0.574, Seconds: 68.39
# Epoch  20/100 Batch  420/468 - Loss:  0.527, Seconds: 54.59
# Epoch  20/100 Batch  440/468 - Loss:  0.538, Seconds: 57.96
# Epoch  20/100 Batch  460/468 - Loss:  0.643, Seconds: 59.00
# Average loss for this update: 0.591
# No Improvement.
# Epoch  21/100 Batch   20/468 - Loss:  0.723, Seconds: 61.85
# Epoch  21/100 Batch   40/468 - Loss:  0.652, Seconds: 61.66
# Epoch  21/100 Batch   60/468 - Loss:  0.615, Seconds: 53.43
# Epoch  21/100 Batch   80/468 - Loss:  0.584, Seconds: 67.43
# Epoch  21/100 Batch  100/468 - Loss:  0.586, Seconds: 57.84
# Epoch  21/100 Batch  120/468 - Loss:  0.543, Seconds: 58.68
# Epoch  21/100 Batch  140/468 - Loss:  0.539, Seconds: 58.49
# Average loss for this update: 0.603
# No Improvement.
# Epoch  21/100 Batch  160/468 - Loss:  0.559, Seconds: 66.16
# Epoch  21/100 Batch  180/468 - Loss:  0.584, Seconds: 62.21
# Epoch  21/100 Batch  200/468 - Loss:  0.580, Seconds: 53.41
# Epoch  21/100 Batch  220/468 - Loss:  0.568, Seconds: 57.90
# Epoch  21/100 Batch  240/468 - Loss:  0.559, Seconds: 44.80
# Epoch  21/100 Batch  260/468 - Loss:  0.524, Seconds: 58.51
# Epoch  21/100 Batch  280/468 - Loss:  0.489, Seconds: 68.22
# Epoch  21/100 Batch  300/468 - Loss:  0.573, Seconds: 58.08
# Average loss for this update: 0.549
# New Record!
# Epoch  21/100 Batch  320/468 - Loss:  0.533, Seconds: 58.22
# Epoch  21/100 Batch  340/468 - Loss:  0.613, Seconds: 49.26
# Epoch  21/100 Batch  360/468 - Loss:  0.592, Seconds: 67.44
# Epoch  21/100 Batch  380/468 - Loss:  0.546, Seconds: 67.09
# Epoch  21/100 Batch  400/468 - Loss:  0.565, Seconds: 67.37
# Epoch  21/100 Batch  420/468 - Loss:  0.510, Seconds: 54.77
# Epoch  21/100 Batch  440/468 - Loss:  0.533, Seconds: 58.46
# Epoch  21/100 Batch  460/468 - Loss:  0.609, Seconds: 58.43
# Average loss for this update: 0.573
# No Improvement.
# Epoch  22/100 Batch   20/468 - Loss:  0.709, Seconds: 62.39
# Epoch  22/100 Batch   40/468 - Loss:  0.634, Seconds: 62.37
# Epoch  22/100 Batch   60/468 - Loss:  0.600, Seconds: 52.85
# Epoch  22/100 Batch   80/468 - Loss:  0.573, Seconds: 67.12
# Epoch  22/100 Batch  100/468 - Loss:  0.574, Seconds: 57.62
# Epoch  22/100 Batch  120/468 - Loss:  0.522, Seconds: 57.55
# Epoch  22/100 Batch  140/468 - Loss:  0.528, Seconds: 58.07
# Average loss for this update: 0.588
# No Improvement.
# Epoch  22/100 Batch  160/468 - Loss:  0.544, Seconds: 66.88
# Epoch  22/100 Batch  180/468 - Loss:  0.573, Seconds: 62.59
# Epoch  22/100 Batch  200/468 - Loss:  0.592, Seconds: 53.00
# Epoch  22/100 Batch  220/468 - Loss:  0.561, Seconds: 57.78
# Epoch  22/100 Batch  240/468 - Loss:  0.549, Seconds: 44.99
# Epoch  22/100 Batch  260/468 - Loss:  0.521, Seconds: 58.07
# Epoch  22/100 Batch  280/468 - Loss:  0.464, Seconds: 67.47
# Epoch  22/100 Batch  300/468 - Loss:  0.568, Seconds: 57.77
# Average loss for this update: 0.542
# New Record!
# Epoch  22/100 Batch  320/468 - Loss:  0.526, Seconds: 58.93
# Epoch  22/100 Batch  340/468 - Loss:  0.581, Seconds: 50.46
# Epoch  22/100 Batch  360/468 - Loss:  0.567, Seconds: 67.25
# Epoch  22/100 Batch  380/468 - Loss:  0.539, Seconds: 67.47
# Epoch  22/100 Batch  400/468 - Loss:  0.554, Seconds: 68.26
# Epoch  22/100 Batch  420/468 - Loss:  0.499, Seconds: 55.19
# Epoch  22/100 Batch  440/468 - Loss:  0.521, Seconds: 58.28
# Epoch  22/100 Batch  460/468 - Loss:  0.584, Seconds: 58.40
# Average loss for this update: 0.555
# No Improvement.
# Epoch  23/100 Batch   20/468 - Loss:  0.702, Seconds: 61.98
# Epoch  23/100 Batch   40/468 - Loss:  0.628, Seconds: 63.62
# Epoch  23/100 Batch   60/468 - Loss:  0.577, Seconds: 53.43
# Epoch  23/100 Batch   80/468 - Loss:  0.561, Seconds: 67.56
# Epoch  23/100 Batch  100/468 - Loss:  0.563, Seconds: 58.42
# Epoch  23/100 Batch  120/468 - Loss:  0.519, Seconds: 57.98
# Epoch  23/100 Batch  140/468 - Loss:  0.535, Seconds: 57.16
# Average loss for this update: 0.582
# No Improvement.
# Epoch  23/100 Batch  160/468 - Loss:  0.550, Seconds: 66.27
# Epoch  23/100 Batch  180/468 - Loss:  0.554, Seconds: 63.41
# Epoch  23/100 Batch  200/468 - Loss:  0.583, Seconds: 53.90
# Epoch  23/100 Batch  220/468 - Loss:  0.552, Seconds: 57.95
# Epoch  23/100 Batch  240/468 - Loss:  0.530, Seconds: 44.81
# Epoch  23/100 Batch  260/468 - Loss:  0.503, Seconds: 58.40
# Epoch  23/100 Batch  280/468 - Loss:  0.460, Seconds: 67.31
# Epoch  23/100 Batch  300/468 - Loss:  0.546, Seconds: 58.66
# Average loss for this update: 0.528
# New Record!
# Epoch  23/100 Batch  320/468 - Loss:  0.499, Seconds: 58.18
# Epoch  23/100 Batch  340/468 - Loss:  0.586, Seconds: 49.99
# Epoch  23/100 Batch  360/468 - Loss:  0.552, Seconds: 67.02
# Epoch  23/100 Batch  380/468 - Loss:  0.522, Seconds: 67.14
# Epoch  23/100 Batch  400/468 - Loss:  0.530, Seconds: 67.18
# Epoch  23/100 Batch  420/468 - Loss:  0.487, Seconds: 53.52
# Epoch  23/100 Batch  440/468 - Loss:  0.505, Seconds: 58.86
# Epoch  23/100 Batch  460/468 - Loss:  0.569, Seconds: 60.72
# Average loss for this update: 0.539
# No Improvement.
# Epoch  24/100 Batch   20/468 - Loss:  0.664, Seconds: 61.94
# Epoch  24/100 Batch   40/468 - Loss:  0.608, Seconds: 62.06
# Epoch  24/100 Batch   60/468 - Loss:  0.562, Seconds: 52.99
# Epoch  24/100 Batch   80/468 - Loss:  0.542, Seconds: 66.93
# Epoch  24/100 Batch  100/468 - Loss:  0.542, Seconds: 57.98
# Epoch  24/100 Batch  120/468 - Loss:  0.499, Seconds: 57.78
# Epoch  24/100 Batch  140/468 - Loss:  0.488, Seconds: 57.76
# Average loss for this update: 0.555
# No Improvement.
# Epoch  24/100 Batch  160/468 - Loss:  0.514, Seconds: 66.85
# Epoch  24/100 Batch  180/468 - Loss:  0.543, Seconds: 62.65
# Epoch  24/100 Batch  200/468 - Loss:  0.557, Seconds: 53.92
# Epoch  24/100 Batch  220/468 - Loss:  0.524, Seconds: 58.30
# Epoch  24/100 Batch  240/468 - Loss:  0.510, Seconds: 45.17
# Epoch  24/100 Batch  260/468 - Loss:  0.479, Seconds: 57.65
# Epoch  24/100 Batch  280/468 - Loss:  0.445, Seconds: 67.58
# Epoch  24/100 Batch  300/468 - Loss:  0.519, Seconds: 59.14
# Average loss for this update: 0.509
# New Record!
# Epoch  24/100 Batch  320/468 - Loss:  0.509, Seconds: 58.08
# Epoch  24/100 Batch  340/468 - Loss:  0.567, Seconds: 49.98
# Epoch  24/100 Batch  360/468 - Loss:  0.541, Seconds: 67.33
# Epoch  24/100 Batch  380/468 - Loss:  0.511, Seconds: 68.18
# Epoch  24/100 Batch  400/468 - Loss:  0.511, Seconds: 69.02
# Epoch  24/100 Batch  420/468 - Loss:  0.471, Seconds: 54.80
# Epoch  24/100 Batch  440/468 - Loss:  0.495, Seconds: 59.43
# Epoch  24/100 Batch  460/468 - Loss:  0.562, Seconds: 58.48
# Average loss for this update: 0.527
# No Improvement.
# Epoch  25/100 Batch   20/468 - Loss:  0.654, Seconds: 61.98
# Epoch  25/100 Batch   40/468 - Loss:  0.592, Seconds: 63.15
# Epoch  25/100 Batch   60/468 - Loss:  0.551, Seconds: 53.59
# Epoch  25/100 Batch   80/468 - Loss:  0.517, Seconds: 66.99
# Epoch  25/100 Batch  100/468 - Loss:  0.528, Seconds: 58.13
# Epoch  25/100 Batch  120/468 - Loss:  0.498, Seconds: 58.09
# Epoch  25/100 Batch  140/468 - Loss:  0.466, Seconds: 57.36
# Average loss for this update: 0.541
# No Improvement.
# Epoch  25/100 Batch  160/468 - Loss:  0.504, Seconds: 66.09
# Epoch  25/100 Batch  180/468 - Loss:  0.520, Seconds: 62.39
# Epoch  25/100 Batch  200/468 - Loss:  0.529, Seconds: 54.18
# Epoch  25/100 Batch  220/468 - Loss:  0.502, Seconds: 58.40
# Epoch  25/100 Batch  240/468 - Loss:  0.498, Seconds: 46.25
# Epoch  25/100 Batch  260/468 - Loss:  0.473, Seconds: 57.61
# Epoch  25/100 Batch  280/468 - Loss:  0.426, Seconds: 68.12
# Epoch  25/100 Batch  300/468 - Loss:  0.509, Seconds: 57.79
# Average loss for this update: 0.49
# New Record!
# Epoch  25/100 Batch  320/468 - Loss:  0.477, Seconds: 58.47
# Epoch  25/100 Batch  340/468 - Loss:  0.549, Seconds: 53.10
# Epoch  25/100 Batch  360/468 - Loss:  0.513, Seconds: 67.01
# Epoch  25/100 Batch  380/468 - Loss:  0.494, Seconds: 66.65
# Epoch  25/100 Batch  400/468 - Loss:  0.495, Seconds: 67.41
# Epoch  25/100 Batch  420/468 - Loss:  0.453, Seconds: 54.09
# Epoch  25/100 Batch  440/468 - Loss:  0.493, Seconds: 58.71
# Epoch  25/100 Batch  460/468 - Loss:  0.542, Seconds: 58.12
# Average loss for this update: 0.51
# No Improvement.
# Epoch  26/100 Batch   20/468 - Loss:  0.637, Seconds: 62.61
# Epoch  26/100 Batch   40/468 - Loss:  0.582, Seconds: 62.14
# Epoch  26/100 Batch   60/468 - Loss:  0.542, Seconds: 53.50
# Epoch  26/100 Batch   80/468 - Loss:  0.520, Seconds: 67.29
# Epoch  26/100 Batch  100/468 - Loss:  0.524, Seconds: 57.48
# Epoch  26/100 Batch  120/468 - Loss:  0.474, Seconds: 57.56
# Epoch  26/100 Batch  140/468 - Loss:  0.466, Seconds: 58.42
# Average loss for this update: 0.532
# No Improvement.
# Epoch  26/100 Batch  160/468 - Loss:  0.501, Seconds: 67.06
# Epoch  26/100 Batch  180/468 - Loss:  0.535, Seconds: 66.32
# Epoch  26/100 Batch  200/468 - Loss:  0.540, Seconds: 52.87
# Epoch  26/100 Batch  220/468 - Loss:  0.492, Seconds: 58.64
# Epoch  26/100 Batch  240/468 - Loss:  0.482, Seconds: 45.17
# Epoch  26/100 Batch  260/468 - Loss:  0.461, Seconds: 58.44
# Epoch  26/100 Batch  280/468 - Loss:  0.423, Seconds: 66.47
# Epoch  26/100 Batch  300/468 - Loss:  0.494, Seconds: 58.60
# Average loss for this update: 0.486
# New Record!
# Epoch  26/100 Batch  320/468 - Loss:  0.466, Seconds: 58.91
# Epoch  26/100 Batch  340/468 - Loss:  0.542, Seconds: 49.45
# Epoch  26/100 Batch  360/468 - Loss:  0.499, Seconds: 68.20
# Epoch  26/100 Batch  380/468 - Loss:  0.487, Seconds: 67.98
# Epoch  26/100 Batch  400/468 - Loss:  0.492, Seconds: 67.21
# Epoch  26/100 Batch  420/468 - Loss:  0.454, Seconds: 54.62
# Epoch  26/100 Batch  440/468 - Loss:  0.472, Seconds: 58.50
# Epoch  26/100 Batch  460/468 - Loss:  0.554, Seconds: 59.31
# Average loss for this update: 0.505
# No Improvement.
# Epoch  27/100 Batch   20/468 - Loss:  0.612, Seconds: 61.61
# Epoch  27/100 Batch   40/468 - Loss:  0.557, Seconds: 62.20
# Epoch  27/100 Batch   60/468 - Loss:  0.518, Seconds: 53.37
# Epoch  27/100 Batch   80/468 - Loss:  0.507, Seconds: 66.09
# Epoch  27/100 Batch  100/468 - Loss:  0.516, Seconds: 57.75
# Epoch  27/100 Batch  120/468 - Loss:  0.450, Seconds: 57.43
# Epoch  27/100 Batch  140/468 - Loss:  0.467, Seconds: 57.82
# Average loss for this update: 0.516
# No Improvement.
# Epoch  27/100 Batch  160/468 - Loss:  0.487, Seconds: 66.80
# Epoch  27/100 Batch  180/468 - Loss:  0.509, Seconds: 62.97
# Epoch  27/100 Batch  200/468 - Loss:  0.523, Seconds: 53.97
# Epoch  27/100 Batch  220/468 - Loss:  0.487, Seconds: 58.38
# Epoch  27/100 Batch  240/468 - Loss:  0.475, Seconds: 45.27
# Epoch  27/100 Batch  260/468 - Loss:  0.462, Seconds: 57.80
# Epoch  27/100 Batch  280/468 - Loss:  0.425, Seconds: 67.02
# Epoch  27/100 Batch  300/468 - Loss:  0.486, Seconds: 57.49
# Average loss for this update: 0.478
# New Record!
# Epoch  27/100 Batch  320/468 - Loss:  0.465, Seconds: 60.16
# Epoch  27/100 Batch  340/468 - Loss:  0.514, Seconds: 50.74
# Epoch  27/100 Batch  360/468 - Loss:  0.501, Seconds: 67.54
# Epoch  27/100 Batch  380/468 - Loss:  0.483, Seconds: 68.11
# Epoch  27/100 Batch  400/468 - Loss:  0.473, Seconds: 67.40
# Epoch  27/100 Batch  420/468 - Loss:  0.460, Seconds: 55.57
# Epoch  27/100 Batch  440/468 - Loss:  0.487, Seconds: 58.65
# Epoch  27/100 Batch  460/468 - Loss:  0.538, Seconds: 58.71
# Average loss for this update: 0.497
# No Improvement.
# Epoch  28/100 Batch   20/468 - Loss:  0.611, Seconds: 61.57
# Epoch  28/100 Batch   40/468 - Loss:  0.570, Seconds: 62.55
# Epoch  28/100 Batch   60/468 - Loss:  0.529, Seconds: 54.21
# Epoch  28/100 Batch   80/468 - Loss:  0.494, Seconds: 68.01
# Epoch  28/100 Batch  100/468 - Loss:  0.513, Seconds: 57.96
# Epoch  28/100 Batch  120/468 - Loss:  0.455, Seconds: 57.63
# Epoch  28/100 Batch  140/468 - Loss:  0.452, Seconds: 57.82
# Average loss for this update: 0.515
# No Improvement.
# Epoch  28/100 Batch  160/468 - Loss:  0.482, Seconds: 67.21
# Epoch  28/100 Batch  180/468 - Loss:  0.504, Seconds: 62.52
# Epoch  28/100 Batch  200/468 - Loss:  0.536, Seconds: 54.27
# Epoch  28/100 Batch  220/468 - Loss:  0.487, Seconds: 58.14
# Epoch  28/100 Batch  240/468 - Loss:  0.480, Seconds: 45.32
# Epoch  28/100 Batch  260/468 - Loss:  0.441, Seconds: 59.19
# Epoch  28/100 Batch  280/468 - Loss:  0.406, Seconds: 67.39
# Epoch  28/100 Batch  300/468 - Loss:  0.494, Seconds: 58.01
# Average loss for this update: 0.475
# New Record!
# Epoch  28/100 Batch  320/468 - Loss:  0.452, Seconds: 58.72
# Epoch  28/100 Batch  340/468 - Loss:  0.534, Seconds: 49.28
# Epoch  28/100 Batch  360/468 - Loss:  0.496, Seconds: 67.04
# Epoch  28/100 Batch  380/468 - Loss:  0.472, Seconds: 67.64
# Epoch  28/100 Batch  400/468 - Loss:  0.474, Seconds: 67.93
# Epoch  28/100 Batch  420/468 - Loss:  0.441, Seconds: 55.06
# Epoch  28/100 Batch  440/468 - Loss:  0.457, Seconds: 58.24
# Epoch  28/100 Batch  460/468 - Loss:  0.515, Seconds: 58.39
# Average loss for this update: 0.488
# No Improvement.
# Epoch  29/100 Batch   20/468 - Loss:  0.583, Seconds: 62.29
# Epoch  29/100 Batch   40/468 - Loss:  0.542, Seconds: 63.10
# Epoch  29/100 Batch   60/468 - Loss:  0.513, Seconds: 53.68
# Epoch  29/100 Batch   80/468 - Loss:  0.483, Seconds: 67.04
# Epoch  29/100 Batch  100/468 - Loss:  0.487, Seconds: 59.64
# Epoch  29/100 Batch  120/468 - Loss:  0.442, Seconds: 57.88
# Epoch  29/100 Batch  140/468 - Loss:  0.438, Seconds: 57.75
# Average loss for this update: 0.496
# No Improvement.
# Epoch  29/100 Batch  160/468 - Loss:  0.458, Seconds: 67.07
# Epoch  29/100 Batch  180/468 - Loss:  0.492, Seconds: 62.81
# Epoch  29/100 Batch  200/468 - Loss:  0.496, Seconds: 55.41
# Epoch  29/100 Batch  220/468 - Loss:  0.478, Seconds: 57.87
# Epoch  29/100 Batch  240/468 - Loss:  0.461, Seconds: 45.44
# Epoch  29/100 Batch  260/468 - Loss:  0.452, Seconds: 58.11
# Epoch  29/100 Batch  280/468 - Loss:  0.407, Seconds: 67.95
# Epoch  29/100 Batch  300/468 - Loss:  0.470, Seconds: 58.71
# Average loss for this update: 0.46
# New Record!
# Epoch  29/100 Batch  320/468 - Loss:  0.430, Seconds: 58.73
# Epoch  29/100 Batch  340/468 - Loss:  0.497, Seconds: 50.10
# Epoch  29/100 Batch  360/468 - Loss:  0.482, Seconds: 67.75
# Epoch  29/100 Batch  380/468 - Loss:  0.450, Seconds: 67.65
# Epoch  29/100 Batch  400/468 - Loss:  0.457, Seconds: 67.44
# Epoch  29/100 Batch  420/468 - Loss:  0.423, Seconds: 53.64
# Epoch  29/100 Batch  440/468 - Loss:  0.447, Seconds: 58.84
# Epoch  29/100 Batch  460/468 - Loss:  0.514, Seconds: 58.48
# Average loss for this update: 0.471
# No Improvement.
# Epoch  30/100 Batch   20/468 - Loss:  0.583, Seconds: 61.47
# Epoch  30/100 Batch   40/468 - Loss:  0.524, Seconds: 62.43
# Epoch  30/100 Batch   60/468 - Loss:  0.493, Seconds: 53.03
# Epoch  30/100 Batch   80/468 - Loss:  0.480, Seconds: 66.65
# Epoch  30/100 Batch  100/468 - Loss:  0.477, Seconds: 58.10
# Epoch  30/100 Batch  120/468 - Loss:  0.436, Seconds: 57.67
# Epoch  30/100 Batch  140/468 - Loss:  0.434, Seconds: 60.23
# Average loss for this update: 0.487
# No Improvement.
# Epoch  30/100 Batch  160/468 - Loss:  0.461, Seconds: 66.35
# Epoch  30/100 Batch  180/468 - Loss:  0.471, Seconds: 62.20
# Epoch  30/100 Batch  200/468 - Loss:  0.487, Seconds: 53.28
# Epoch  30/100 Batch  220/468 - Loss:  0.451, Seconds: 58.15
# Epoch  30/100 Batch  240/468 - Loss:  0.444, Seconds: 44.85
# Epoch  30/100 Batch  260/468 - Loss:  0.432, Seconds: 57.98
# Epoch  30/100 Batch  280/468 - Loss:  0.394, Seconds: 68.31
# Epoch  30/100 Batch  300/468 - Loss:  0.468, Seconds: 59.02
# Average loss for this update: 0.447
# New Record!
# Epoch  30/100 Batch  320/468 - Loss:  0.438, Seconds: 58.94
# Epoch  30/100 Batch  340/468 - Loss:  0.493, Seconds: 49.41
# Epoch  30/100 Batch  360/468 - Loss:  0.476, Seconds: 67.02
# Epoch  30/100 Batch  380/468 - Loss:  0.434, Seconds: 67.33
# Epoch  30/100 Batch  400/468 - Loss:  0.442, Seconds: 67.51
# Epoch  30/100 Batch  420/468 - Loss:  0.412, Seconds: 53.93
# Epoch  30/100 Batch  440/468 - Loss:  0.441, Seconds: 58.60
# Epoch  30/100 Batch  460/468 - Loss:  0.497, Seconds: 58.62
# Average loss for this update: 0.462
# No Improvement.
# Epoch  31/100 Batch   20/468 - Loss:  0.557, Seconds: 62.21
# Epoch  31/100 Batch   40/468 - Loss:  0.522, Seconds: 62.53
# Epoch  31/100 Batch   60/468 - Loss:  0.477, Seconds: 53.79
# Epoch  31/100 Batch   80/468 - Loss:  0.464, Seconds: 66.58
# Epoch  31/100 Batch  100/468 - Loss:  0.471, Seconds: 57.89
# Epoch  31/100 Batch  120/468 - Loss:  0.422, Seconds: 59.80
# Epoch  31/100 Batch  140/468 - Loss:  0.419, Seconds: 58.14
# Average loss for this update: 0.474
# No Improvement.
# Epoch  31/100 Batch  160/468 - Loss:  0.441, Seconds: 67.32
# Epoch  31/100 Batch  180/468 - Loss:  0.456, Seconds: 63.71
# Epoch  31/100 Batch  200/468 - Loss:  0.477, Seconds: 53.81
# Epoch  31/100 Batch  220/468 - Loss:  0.461, Seconds: 57.95
# Epoch  31/100 Batch  240/468 - Loss:  0.451, Seconds: 45.78
# Epoch  31/100 Batch  260/468 - Loss:  0.409, Seconds: 58.43
# Epoch  31/100 Batch  280/468 - Loss:  0.390, Seconds: 66.46
# Epoch  31/100 Batch  300/468 - Loss:  0.457, Seconds: 57.49
# Average loss for this update: 0.439
# New Record!
# Epoch  31/100 Batch  320/468 - Loss:  0.430, Seconds: 59.59
# Epoch  31/100 Batch  340/468 - Loss:  0.481, Seconds: 49.28
# Epoch  31/100 Batch  360/468 - Loss:  0.458, Seconds: 67.34
# Epoch  31/100 Batch  380/468 - Loss:  0.436, Seconds: 68.24
# Epoch  31/100 Batch  400/468 - Loss:  0.449, Seconds: 67.63
# Epoch  31/100 Batch  420/468 - Loss:  0.409, Seconds: 54.44
# Epoch  31/100 Batch  440/468 - Loss:  0.430, Seconds: 58.31
# Epoch  31/100 Batch  460/468 - Loss:  0.484, Seconds: 58.19
# Average loss for this update: 0.454
# No Improvement.
# Epoch  32/100 Batch   20/468 - Loss:  0.566, Seconds: 62.01
# Epoch  32/100 Batch   40/468 - Loss:  0.497, Seconds: 62.58
# Epoch  32/100 Batch   60/468 - Loss:  0.469, Seconds: 54.20
# Epoch  32/100 Batch   80/468 - Loss:  0.440, Seconds: 66.61
# Epoch  32/100 Batch  100/468 - Loss:  0.452, Seconds: 57.42
# Epoch  32/100 Batch  120/468 - Loss:  0.402, Seconds: 57.84
# Epoch  32/100 Batch  140/468 - Loss:  0.416, Seconds: 58.90
# Average loss for this update: 0.46
# No Improvement.
# Epoch  32/100 Batch  160/468 - Loss:  0.431, Seconds: 66.60
# Epoch  32/100 Batch  180/468 - Loss:  0.443, Seconds: 62.97
# Epoch  32/100 Batch  200/468 - Loss:  0.463, Seconds: 55.44
# Epoch  32/100 Batch  220/468 - Loss:  0.437, Seconds: 58.31
# Epoch  32/100 Batch  240/468 - Loss:  0.436, Seconds: 45.91
# Epoch  32/100 Batch  260/468 - Loss:  0.404, Seconds: 58.61
# Epoch  32/100 Batch  280/468 - Loss:  0.381, Seconds: 67.38
# Epoch  32/100 Batch  300/468 - Loss:  0.452, Seconds: 58.24
# Average loss for this update: 0.428
# New Record!
# Epoch  32/100 Batch  320/468 - Loss:  0.411, Seconds: 59.76
# Epoch  32/100 Batch  340/468 - Loss:  0.463, Seconds: 49.45
# Epoch  32/100 Batch  360/468 - Loss:  0.449, Seconds: 66.57
# Epoch  32/100 Batch  380/468 - Loss:  0.434, Seconds: 67.25
# Epoch  32/100 Batch  400/468 - Loss:  0.422, Seconds: 67.07
# Epoch  32/100 Batch  420/468 - Loss:  0.396, Seconds: 55.20
# Epoch  32/100 Batch  440/468 - Loss:  0.426, Seconds: 58.50
# Epoch  32/100 Batch  460/468 - Loss:  0.461, Seconds: 58.66
# Average loss for this update: 0.44
# No Improvement.
# Epoch  33/100 Batch   20/468 - Loss:  0.544, Seconds: 61.87
# Epoch  33/100 Batch   40/468 - Loss:  0.486, Seconds: 62.55
# Epoch  33/100 Batch   60/468 - Loss:  0.468, Seconds: 54.08
# Epoch  33/100 Batch   80/468 - Loss:  0.450, Seconds: 66.65
# Epoch  33/100 Batch  100/468 - Loss:  0.465, Seconds: 57.58
# Epoch  33/100 Batch  120/468 - Loss:  0.417, Seconds: 57.80
# Epoch  33/100 Batch  140/468 - Loss:  0.412, Seconds: 58.17
# Average loss for this update: 0.462
# No Improvement.
# Epoch  33/100 Batch  160/468 - Loss:  0.439, Seconds: 66.76
# Epoch  33/100 Batch  180/468 - Loss:  0.454, Seconds: 62.37
# Epoch  33/100 Batch  200/468 - Loss:  0.463, Seconds: 54.38
# Epoch  33/100 Batch  220/468 - Loss:  0.439, Seconds: 57.81
# Epoch  33/100 Batch  240/468 - Loss:  0.449, Seconds: 44.98
# Epoch  33/100 Batch  260/468 - Loss:  0.405, Seconds: 58.13
# Epoch  33/100 Batch  280/468 - Loss:  0.372, Seconds: 67.76
# Epoch  33/100 Batch  300/468 - Loss:  0.442, Seconds: 58.72
# Average loss for this update: 0.428
# No Improvement.
# Stopping Training.

# %% [markdown]
# # 5. Generating and comparing summaries

# %%
def text_to_seq(text):
    '''Prepare the text for the model'''
    
    text = clean_text(text)
    return [vocab_to_int.get(word, vocab_to_int['<UNK>']) for word in text.split()]

def summarize_text(input_text):
    # measure time
    t0 = time.time()
    text = text_to_seq(input_text)

    checkpoint = "./best_model.ckpt"

    loaded_graph = tf.Graph()
    with tf.Session(graph=loaded_graph) as sess:
        # Load saved model
        loader = tf.train.import_meta_graph(checkpoint + '.meta')
        loader.restore(sess, checkpoint)

        input_data = loaded_graph.get_tensor_by_name('input:0')
        logits = loaded_graph.get_tensor_by_name('predictions:0')
        text_length = loaded_graph.get_tensor_by_name('text_length:0')
        summary_length = loaded_graph.get_tensor_by_name('summary_length:0')
        keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

        #Multiply by batch_size to match the model's input parameters
        answer_logits = sess.run(logits, {input_data: [text]*batch_size, 
                                          summary_length: [np.random.randint(5,8)], 
                                          text_length: [len(text)]*batch_size,
                                          keep_prob: 1.0})[0] 

    # Remove the padding from the text
    pad = vocab_to_int["<PAD>"] 
    print(" ".join([int_to_vocab[i] for i in answer_logits if i != pad]))
    
    t1 = time.time()
    print("Time taken to summarize:",t1-t0)

# %%
# import sumy's text_rank module as an example of extractive summary
from sumy.summarizers.text_rank import TextRankSummarizer
from nltk.corpus import stopwords
from nltk.tokenize import punkt
from sumy.nlp.stemmers import Stemmer
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer

def text_rank_summary(text, language = 'english',length = 1):
    # measure time
    t0 = time.time()
    
    parser = PlaintextParser(text, Tokenizer(language))
    stemmer = Stemmer(language)
    summarizer = TextRankSummarizer()
    summarizer.stop_words = stopwords.words('english')
    
    for i in summarizer(parser.document,length):
        print(i)
    
    t1 = time.time()
    print("Time taken to summarize:", t1 - t0)

# %%
# comparing text
def compare_text(text, length = 1):
    # original text
    print("----------ORIGINAL TEXT----------")
    print(text)

    # Abstractive summarization
    print("\n----------ABSTRACTIVE SUMMARIZATION----------")
    summarize_text(text)

    # Extractive summarization
    print("\n----------EXTRACTIVE SUMMARIZATION----------")
    print(text_rank_summary(text),length)

# %%
example = """For those of us without a two week vacation to devote to this tome, I would like to see a Clif's Notes version. Maybe 10,000 random numbers? \
SPOILER ALERT: They just pretty much stay random the whole time, no plot twists or anything. I mean if you've seen one random number, you've seen them all. In a slap in the face of randomness, the very randomness of it got repetitive after a few pages. Save yourself the time, and if you need a random number, just sort of think of a random number in your head and write it down. Odds are its in the book already, and you saved yourself $80.\
On the plus side, great comments. Please read my upcoming meta-pop-economics book, "Absurdity, Humor, and Metacommentary in Current Anonymous Internet Communication, A Case Study: Literary Criticism of the Amazon.com Comments Section for the Book 'A Million Random Digits with 100,000 Normal Deviates' by the Rand Corporation." Coming soon to Amazon.com."""

compare_text(example)
# Out:
# ----------ORIGINAL TEXT----------
# For those of us without a two week vacation to devote to this tome, I would like to see a Clif's Notes version. Maybe 10,000 random numbers? SPOILER ALERT: They just pretty much stay random the whole time, no plot twists or anything. I mean if you've seen one random number, you've seen them all. In a slap in the face of randomness, the very randomness of it got repetitive after a few pages. Save yourself the time, and if you need a random number, just sort of think of a random number in your head and write it down. Odds are its in the book already, and you saved yourself $80.On the plus side, great comments. Please read my upcoming meta-pop-economics book, "Absurdity, Humor, and Metacommentary in Current Anonymous Internet Communication, A Case Study: Literary Criticism of the Amazon.com Comments Section for the Book 'A Million Random Digits with 100,000 Normal Deviates' by the Rand Corporation." Coming soon to Amazon.com.
#
# ----------ABSTRACTIVE SUMMARIZATION----------
# INFO:tensorflow:Restoring parameters from ./best_model.ckpt
# not what i expected
# Time taken to summarize: 25.418362140655518
#
# ----------EXTRACTIVE SUMMARIZATION----------
# Save yourself the time, and if you need a random number, just sort of think of a random number in your head and write it down.
# Time taken to summarize: 0.004300117492675781
# None 1

# %%
example2 = """Ferrero Rocher is one of my favorite candies so I decided to order some as a Valentine’s gift for myself. \
The package arrived on time and the appropriate protection was used as this product did not arrive damaged or cracked. \
The product was just as described – 2 tiers of 24 candies on each level, for a total of 48 pieces. \
Unfortunately, when I opened the candy wrapper I noticed the outer chocolate shell looked off-color and had a white dried-out tint to it. I proceeded to eat the candy and found that it tasted a bit off and seemed stale. \
I thought maybe it was just my taste buds or that it was possibly just that one piece. So I went ahead and ate a couple more pieces. Every piece tasted just like the first one – stale! \
I decided to try and find the LOT codes to check out the expiration date. Sure enough, these chocolates were beyond expired! \
I am extremely disappointed and unhappy with my purchase. I know mistakes can happen, so if this company is able to fix this problem, I will post an update. However, at this time I do not recommend this product from this seller."""

compare_text(example2)
# Out:
# ----------ORIGINAL TEXT----------
# Ferrero Rocher is one of my favorite candies so I decided to order some as a Valentine’s gift for myself. The package arrived on time and the appropriate protection was used as this product did not arrive damaged or cracked. The product was just as described – 2 tiers of 24 candies on each level, for a total of 48 pieces. Unfortunately, when I opened the candy wrapper I noticed the outer chocolate shell looked off-color and had a white dried-out tint to it. I proceeded to eat the candy and found that it tasted a bit off and seemed stale. I thought maybe it was just my taste buds or that it was possibly just that one piece. So I went ahead and ate a couple more pieces. Every piece tasted just like the first one – stale! I decided to try and find the LOT codes to check out the expiration date. Sure enough, these chocolates were beyond expired! I am extremely disappointed and unhappy with my purchase. I know mistakes can happen, so if this company is able to fix this problem, I will post an update. However, at this time I do not recommend this product from this seller.
#
# ----------ABSTRACTIVE SUMMARIZATION----------
# INFO:tensorflow:Restoring parameters from ./best_model.ckpt
# not as good as i would
# Time taken to summarize: 25.62043786048889
#
# ----------EXTRACTIVE SUMMARIZATION----------
# Every piece tasted just like the first one – stale!
# Time taken to summarize: 0.005447864532470703
# None 1

# %%
example3 = """Out of all the furniture I ever bought online, this was by far the best choice... Both in quality and price! I seriously have one of these rugs in every room of my house now. I ordered the 6-7 x 9' rug in Turquoise on 01/17/16 for $129 w/FREE Shipping. It was delivered in pristine condition less than a week later. Although it was a risk to buy a rug without seeing first in person, I was very happy with the outcome and highly recommend it to anyone looking for a good quality yet affordable shag carpet. In fact, I've purchased several other rugs like this in various colors/sizes and have found them all to be of the same high quality.\
APPEARANCE | This rug is absolutely gorgeous. The pile is just the right length and the shag is has a comfortable cushy texture that also looks amazing. It's all over soft and cozy and is the perfect area for performing my daily yoga routine. The material is thick, heavy (in a good way) and feels luxurious. My family members and guests love to sit on it. I've received many compliments (from
both males and females of varying ages) and it seems like everyone who enters the house is drawn to sitting on it!\
SHEDDING | It hardly sheds (only 4 or 5 threads fell out over the 1st month). I rarely find any loose threads. It's held up well to vacuuming, even with a Shop Vac.\
STAINING/CLEANING | The rug is resistant to staining and spot cleans easily. Unlike virtually everything else in my house, it doesn't attract fur from my large German Shepard (who also loves to lay on it)! It's also "kid-friendly," meaning that it's easy to keep clean and durable.\
COMPETITION | I spent a lot of time researching shag rugs on Amazon, Wayfair, and Overstock.com prior to going with this one. Sweet Home brand was by far the best priced... It had a lot of positive reviews and I feel they were accurate. I'll definitely continue to buy from Sweet Home brand.\
COLOR | The Turquoise is true to color, just as pictured. It's a light turquoise... Definitely NOT teal or baby blue. It's been easy to match with other turquoise-colored decor. I also have the Trellis Design in Charcoal-Cream. It's an attractive dark grey, definitely not black or blue, and the cream is... well, cream. I also have one in the lighter grey (also trellis design). It's best described as a neutral, maybe slightly cool toned (as opposed to warm) grey and the trellis pattern is also a light-medium cream.\
PLACEMENT | This huge rug rolled out nicely and stays in place. It's didn't buckle or roll up on itself, even on the 1st day. Note that I have one over carpet, one on wood flooring, and the others over tile. They retain their grip well on each type of surface and I do NOT use any rug pads under them.\
COORDINATION | This rug adds visual interest to the room in terms of color and texture. Since I decorate with lots of white, silver, grey and clear lucite pieces, the turquoise prevents the room from looking sterile or drab. In order to tie in the vibrant color, I ordered some faux fur pillow covers in turquoise from the Euphoria CaliTime brand. The color isn't exact but it's close enough and looks awesome. (Sweet Home also makes a faux fur pillow in turquoise which appears to be an exact match but I passed on it as the cover is not detachable and I like to have the ability to wash them.) The overall look has major swag! It's chick, yet inviting and comfortable.\
INSPECT | When I bought a 2nd rug (the Trellis design in Charcoal/Cream), I ordered it in 6'7" x 9'3" but received one that was 4'11" 6'8." I advise other buyers to inspect the size and confirm it's accurate upon arrival. The seller was SUPER cool about correcting the issue and even allowed me to keep the smaller-sized rug. I found this to be great customer service as returning a rug is NOT an easy task. Therefore, in the event that you do not receive the correct size or color, I urge you to NOT flip out and leave a nasty review.... Give them an opportunity to correct the issue first. Hopefully you'll have a positive experience like I did. """

compare_text(example3)
# Out:
# ----------ORIGINAL TEXT----------
# Out of all the furniture I ever bought online, this was by far the best choice... Both in quality and price! I seriously have one of these rugs in every room of my house now. I ordered the 6-7 x 9' rug in Turquoise on 01/17/16 for $129 w/FREE Shipping. It was delivered in pristine condition less than a week later. Although it was a risk to buy a rug without seeing first in person, I was very happy with the outcome and highly recommend it to anyone looking for a good quality yet affordable shag carpet. In fact, I've purchased several other rugs like this in various colors/sizes and have found them all to be of the same high quality.APPEARANCE | This rug is absolutely gorgeous. The pile is just the right length and the shag is has a comfortable cushy texture that also looks amazing. It's all over soft and cozy and is the perfect area for performing my daily yoga routine. The material is thick, heavy (in a good way) and feels luxurious. My family members and guests love to sit on it. I've received many compliments (from
# both males and females of varying ages) and it seems like everyone who enters the house is drawn to sitting on it!SHEDDING | It hardly sheds (only 4 or 5 threads fell out over the 1st month). I rarely find any loose threads. It's held up well to vacuuming, even with a Shop Vac.STAINING/CLEANING | The rug is resistant to staining and spot cleans easily. Unlike virtually everything else in my house, it doesn't attract fur from my large German Shepard (who also loves to lay on it)! It's also "kid-friendly," meaning that it's easy to keep clean and durable.COMPETITION | I spent a lot of time researching shag rugs on Amazon, Wayfair, and Overstock.com prior to going with this one. Sweet Home brand was by far the best priced... It had a lot of positive reviews and I feel they were accurate. I'll definitely continue to buy from Sweet Home brand.COLOR | The Turquoise is true to color, just as pictured. It's a light turquoise... Definitely NOT teal or baby blue. It's been easy to match with other turquoise-colored decor. I also have the Trellis Design in Charcoal-Cream. It's an attractive dark grey, definitely not black or blue, and the cream is... well, cream. I also have one in the lighter grey (also trellis design). It's best described as a neutral, maybe slightly cool toned (as opposed to warm) grey and the trellis pattern is also a light-medium cream.PLACEMENT | This huge rug rolled out nicely and stays in place. It's didn't buckle or roll up on itself, even on the 1st day. Note that I have one over carpet, one on wood flooring, and the others over tile. They retain their grip well on each type of surface and I do NOT use any rug pads under them.COORDINATION | This rug adds visual interest to the room in terms of color and texture. Since I decorate with lots of white, silver, grey and clear lucite pieces, the turquoise prevents the room from looking sterile or drab. In order to tie in the vibrant color, I ordered some faux fur pillow covers in turquoise from the Euphoria CaliTime brand. The color isn't exact but it's close enough and looks awesome. (Sweet Home also makes a faux fur pillow in turquoise which appears to be an exact match but I passed on it as the cover is not detachable and I like to have the ability to wash them.) The overall look has major swag! It's chick, yet inviting and comfortable.INSPECT | When I bought a 2nd rug (the Trellis design in Charcoal/Cream), I ordered it in 6'7" x 9'3" but received one that was 4'11" 6'8." I advise other buyers to inspect the size and confirm it's accurate upon arrival. The seller was SUPER cool about correcting the issue and even allowed me to keep the smaller-sized rug. I found this to be great customer service as returning a rug is NOT an easy task. Therefore, in the event that you do not receive the correct size or color, I urge you to NOT flip out and leave a nasty review.... Give them an opportunity to correct the issue first. Hopefully you'll have a positive experience like I did.
#
# ----------ABSTRACTIVE SUMMARIZATION----------
# INFO:tensorflow:Restoring parameters from ./best_model.ckpt
# great for people
# Time taken to summarize: 26.88604497909546
#
# ----------EXTRACTIVE SUMMARIZATION----------
# I also have one in the lighter grey (also trellis design).
# Time taken to summarize: 0.030035972595214844
# None 1

# %% [markdown]
# # 6. Conclusion

# %% [markdown]
# As can be seen from the example, seq2seq attention model produces a much more relevant and coherent result. However, it is also much slower than the extractive textrank method. In particular, if we consider the time taken to train the model, abstractive methods can be excruciatingly slow, even with the limited training set used in the context. Depending on the usage (especially in the commercial production settings), abstractive methods may still prove to be limited in practicality.
