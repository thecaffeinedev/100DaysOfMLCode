# %% [markdown]
# # Tooploox Data Scientist Exercise

# %%
from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import h5py
from image_plotting import *
from PIL import Image
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # Due to the lack of a CUDA enambled GPU I have only used $\frac{1}{10}$ of the dataset

# %% [markdown]
# ## 10 random images form each class in the dataset.

# %%
Image.open("presentation_images/10.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x1000 at 0x11931B550>

# %% [markdown]
# # ================================================= =================================================
#
# # Shallow classifier (benchmark)
# ## Test set accuracy = 52 %

# %% [markdown]
# ## HoG for feature extraction and a SVM for classification.

# %% [markdown]
# Explanation why and how

# %% [markdown]
# https://github.com/cthorey/CS231/blob/master/assignment1/cs231n/features.py

# %% [markdown]
# ### Cross validation

# %% [markdown]
# Best parameters:
# * kernel: rbf
# * C = 10
# * gamma = 0.01

# %%
Image.open("presentation_images/shallow_test.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=576x576 at 0x11998CD30>

# %% [markdown]
# # Extracing CNN codes from VGG16

# %% [markdown]
#  layer fc2

# %% [markdown]
# ## embedding them in 2D using t-sne

# %%
Image.open("presentation_images/t-snetraining.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x720 at 0x11931B4A8>

# %% [markdown]
# # Training SVM on top of CNN codes
# ## Test set accuracy = 80 %

# %% [markdown]
# ## optimal hyperparameters: INSER|T HERE

# %%
Image.open("presentation_images/cnn_svm.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=576x576 at 0x11931B630>
